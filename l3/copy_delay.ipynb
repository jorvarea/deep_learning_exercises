# %% [markdown]
# **Lab3-CopyDelayTask.ipnyb**
#
# This simple provided notebook is as initial code for the task of comparing the capacities of Vanilla-RNN and LSTM networks in a sequence memory tasks.
#
# **Lab3 1st task:** understand exactly what this code does (what is the task, and why it make sense to use this task), and then execute it with different parameters in order to extract conclusions of the differences obtained for RNN and LSTM. With the default settings, there is a similar behaviour of both models, and even a worse one from the LSTM, so you task is to look at the learning curves, optimize the parameters and then do a fair comparison of both models.
#
# **To be uploaded to the Virtual Campus:** A pdf file with a short explanation of what the code does (no code), explaining the task, together with a description of your experiments with the final parameters used and your conclusions about the behavior of both models. A figure (the same format or similar to the one printed by the code with your results should be included).

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
import time

# Parameters
input_size = 5 #vector of inputs
hidden_size = 128 #def 32
output_size = input_size
batch_size = 128 # def 32
learning_rate = 0.02 #def 0.01
max_epochs = 50 # def 15
patience = 3  #def 3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
num_runs = 5  # Number of runs to average per delay def:5

# Delay values to test
delays = list(range(1, 30 , 4))  #def (1, 30, 4))

# Data generation
def generate_batch_delay(batch_size, delay, input_size):
    seq_len = delay * 2
    seq = torch.zeros(batch_size, seq_len, input_size)
    seq[:, :delay, :] = (torch.rand(batch_size, delay, input_size) > 0.5).float()
    target = torch.zeros_like(seq)
    target[:, delay:, :] = seq[:, :delay, :]
    return seq.to(device), target.to(device), seq_len

# Models
class VanillaRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.rnn(x)
        return self.fc(out)

class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.lstm(x)
        return self.fc(out)

# Accuracy calculation
def binary_accuracy(output, target):
    preds = (torch.sigmoid(output) > 0.5).float()
    correct = (preds == target).float()
    return correct.mean().item()

# Train model for given delay with early stopping
def train_for_delay_early_stopping(model, delay, model_name="Model", run_num=0, verbose=True):
    seq_len = delay * 2
    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    best_val_loss = float('inf')
    epochs_no_improve = 0
    best_model_state = None
    best_epoch = 0
    early_stopped = False
    epoch_times = []
    
    total_start = time.time()

    for epoch in range(max_epochs):
        epoch_start = time.time()
        
        model.train()
        train_loss = 0.0
        for _ in range(100):
            seq_in, seq_target, _ = generate_batch_delay(batch_size, delay, input_size)
            optimizer.zero_grad()
            output = model(seq_in)
            loss = criterion(output[:, delay:, :], seq_target[:, delay:, :])
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        train_loss /= 100

        # Validation loss
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for _ in range(20):
                seq_in, seq_target, _ = generate_batch_delay(batch_size, delay, input_size)
                output = model(seq_in)
                loss = criterion(output[:, delay:, :], seq_target[:, delay:, :])
                val_loss += loss.item()
        val_loss /= 20
        
        epoch_time = time.time() - epoch_start
        epoch_times.append(epoch_time)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = model.state_dict()
            best_epoch = epoch + 1
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                early_stopped = True
                break
        
        # Early stop si val_loss es prácticamente 0
        if val_loss < 1e-4:
            early_stopped = True
            break

    total_time = time.time() - total_start
    final_epoch = epoch + 1
    avg_epoch_time = np.mean(epoch_times)
    
    if verbose:
        if best_val_loss < 1e-4:
            status = "CONVERGED"  # loss ~0
        elif early_stopped:
            status = "EARLY STOP"  # patience
        else:
            status = "MAX EPOCHS"
        print(f"  {model_name} Run {run_num}: {final_epoch}/{max_epochs} epochs | "
              f"{status} | best@{best_epoch} | "
              f"avg {avg_epoch_time:.2f}s/epoch | total {total_time:.1f}s | "
              f"val_loss: {best_val_loss:.6f}")

    if best_model_state:
        model.load_state_dict(best_model_state)
    
    return model, {
        'epochs': final_epoch,
        'early_stopped': early_stopped,
        'best_epoch': best_epoch,
        'avg_epoch_time': avg_epoch_time,
        'total_time': total_time,
        'best_val_loss': best_val_loss
    }

# Evaluate model accuracy for given delay
def evaluate_for_delay(model, delay, trials=20):
    seq_len = delay * 2
    model.eval()
    acc = 0
    with torch.no_grad():
        for _ in range(trials):
            seq_in, seq_target, _ = generate_batch_delay(batch_size, delay, input_size)
            output = model(seq_in)
            acc += binary_accuracy(output[:, delay:, :], seq_target[:, delay:, :])
    return acc / trials

rnn_accuracies = []
lstm_accuracies = []
all_stats = []  # Para guardar estadísticas detalladas

for delay in delays:
    print(f"\n{'='*60}")
    print(f"DELAY {delay} - {num_runs} runs")
    print('='*60)
    
    rnn_accs = []
    lstm_accs = []
    delay_stats = {'delay': delay, 'rnn': [], 'lstm': []}
    
    for run in range(num_runs):
        # RNN
        rnn = VanillaRNN(input_size, hidden_size, output_size).to(device)
        rnn, rnn_stats = train_for_delay_early_stopping(rnn, delay, "RNN ", run+1)
        rnn_acc = evaluate_for_delay(rnn, delay)
        rnn_accs.append(rnn_acc)
        delay_stats['rnn'].append({**rnn_stats, 'accuracy': rnn_acc})

        # LSTM
        lstm = LSTMModel(input_size, hidden_size, output_size).to(device)
        lstm, lstm_stats = train_for_delay_early_stopping(lstm, delay, "LSTM", run+1)
        lstm_acc = evaluate_for_delay(lstm, delay)
        lstm_accs.append(lstm_acc)
        delay_stats['lstm'].append({**lstm_stats, 'accuracy': lstm_acc})

    rnn_mean = np.mean(rnn_accs)
    lstm_mean = np.mean(lstm_accs)
    rnn_accuracies.append(rnn_mean)
    lstm_accuracies.append(lstm_mean)
    all_stats.append(delay_stats)
    
    print(f"  >> RNN  avg accuracy: {rnn_mean:.4f}")
    print(f"  >> LSTM avg accuracy: {lstm_mean:.4f}")

# Plot accuracy vs delay
plt.figure(figsize=(8,5))
plt.plot(delays, rnn_accuracies, 'o-', label='Vanilla RNN')
plt.plot(delays, lstm_accuracies, 's-', label='LSTM')
plt.xlabel('Delay Length')
plt.ylabel('Accuracy')
plt.title(f'Copy Delay Task: Accuracy vs Delay Length (averaged over {num_runs} runs)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ============================================================
# DELAY 1 - 5 runs
# ============================================================
#   RNN  Run 1: 1/50 epochs | CONVERGED | best@1 | avg 0.20s/epoch | total 0.2s | val_loss: 0.000023
#   LSTM Run 1: 1/50 epochs | CONVERGED | best@1 | avg 0.24s/epoch | total 0.2s | val_loss: 0.000011
#   RNN  Run 2: 1/50 epochs | CONVERGED | best@1 | avg 0.22s/epoch | total 0.2s | val_loss: 0.000016
#   LSTM Run 2: 1/50 epochs | CONVERGED | best@1 | avg 0.23s/epoch | total 0.2s | val_loss: 0.000013
#   RNN  Run 3: 1/50 epochs | CONVERGED | best@1 | avg 0.19s/epoch | total 0.2s | val_loss: 0.000013
#   LSTM Run 3: 1/50 epochs | CONVERGED | best@1 | avg 0.22s/epoch | total 0.2s | val_loss: 0.000014
#   RNN  Run 4: 1/50 epochs | CONVERGED | best@1 | avg 0.20s/epoch | total 0.2s | val_loss: 0.000019
#   LSTM Run 4: 1/50 epochs | CONVERGED | best@1 | avg 0.22s/epoch | total 0.2s | val_loss: 0.000015
#   RNN  Run 5: 1/50 epochs | CONVERGED | best@1 | avg 0.22s/epoch | total 0.2s | val_loss: 0.000019
#   LSTM Run 5: 1/50 epochs | CONVERGED | best@1 | avg 0.22s/epoch | total 0.2s | val_loss: 0.000026
#   >> RNN  avg accuracy: 1.0000
#   >> LSTM avg accuracy: 1.0000
#
# ============================================================
# DELAY 5 - 5 runs
# ============================================================
#   RNN  Run 1: 5/50 epochs | EARLY STOP | best@2 | avg 0.21s/epoch | total 1.0s | val_loss: 0.003654
#   LSTM Run 1: 10/50 epochs | EARLY STOP | best@7 | avg 0.23s/epoch | total 2.3s | val_loss: 0.002398
#   RNN  Run 2: 8/50 epochs | EARLY STOP | best@5 | avg 0.21s/epoch | total 1.7s | val_loss: 0.000128
#   LSTM Run 2: 9/50 epochs | EARLY STOP | best@6 | avg 0.23s/epoch | total 2.1s | val_loss: 0.004774
#   RNN  Run 3: 5/50 epochs | EARLY STOP | best@2 | avg 0.20s/epoch | total 1.0s | val_loss: 0.001868
#   LSTM Run 3: 11/50 epochs | EARLY STOP | best@8 | avg 0.23s/epoch | total 2.5s | val_loss: 0.005177
#   RNN  Run 4: 5/50 epochs | EARLY STOP | best@2 | avg 0.20s/epoch | total 1.0s | val_loss: 0.001634
#   LSTM Run 4: 10/50 epochs | EARLY STOP | best@7 | avg 0.23s/epoch | total 2.3s | val_loss: 0.003548
#   RNN  Run 5: 5/50 epochs | EARLY STOP | best@2 | avg 0.21s/epoch | total 1.1s | val_loss: 0.000843
#   LSTM Run 5: 13/50 epochs | EARLY STOP | best@10 | avg 0.23s/epoch | total 3.0s | val_loss: 0.002742
#   >> RNN  avg accuracy: 0.8326
#   >> LSTM avg accuracy: 0.9976
#
# ============================================================
# DELAY 9 - 5 runs
# ============================================================
#   RNN  Run 1: 6/50 epochs | EARLY STOP | best@3 | avg 0.21s/epoch | total 1.3s | val_loss: 0.694915
#   LSTM Run 1: 13/50 epochs | EARLY STOP | best@10 | avg 0.24s/epoch | total 3.1s | val_loss: 0.003013
#   RNN  Run 2: 4/50 epochs | EARLY STOP | best@1 | avg 0.21s/epoch | total 0.9s | val_loss: 0.695246
#   LSTM Run 2: 18/50 epochs | EARLY STOP | best@15 | avg 0.24s/epoch | total 4.3s | val_loss: 0.000858
#   RNN  Run 3: 6/50 epochs | EARLY STOP | best@3 | avg 0.21s/epoch | total 1.3s | val_loss: 0.567278
#   LSTM Run 3: 23/50 epochs | EARLY STOP | best@20 | avg 0.24s/epoch | total 5.6s | val_loss: 0.000217
#   RNN  Run 4: 5/50 epochs | EARLY STOP | best@2 | avg 0.21s/epoch | total 1.1s | val_loss: 0.693956
#   LSTM Run 4: 19/50 epochs | EARLY STOP | best@16 | avg 0.24s/epoch | total 4.6s | val_loss: 0.005168
#   RNN  Run 5: 5/50 epochs | EARLY STOP | best@2 | avg 0.21s/epoch | total 1.1s | val_loss: 0.689430
#   LSTM Run 5: 16/50 epochs | EARLY STOP | best@13 | avg 0.24s/epoch | total 3.9s | val_loss: 0.005557
#   >> RNN  avg accuracy: 0.5087
#   >> LSTM avg accuracy: 0.9984
#
# ============================================================
# DELAY 13 - 5 runs
# ============================================================
#   RNN  Run 1: 5/50 epochs | EARLY STOP | best@2 | avg 0.22s/epoch | total 1.1s | val_loss: 0.696558
#   LSTM Run 1: 5/50 epochs | EARLY STOP | best@2 | avg 0.25s/epoch | total 1.3s | val_loss: 0.693182
#   RNN  Run 2: 7/50 epochs | EARLY STOP | best@4 | avg 0.22s/epoch | total 1.5s | val_loss: 0.696085
#   LSTM Run 2: 50/50 epochs | MAX EPOCHS | best@48 | avg 0.25s/epoch | total 12.5s | val_loss: 0.000999
#   RNN  Run 3: 6/50 epochs | EARLY STOP | best@3 | avg 0.22s/epoch | total 1.3s | val_loss: 0.694617
#   LSTM Run 3: 50/50 epochs | MAX EPOCHS | best@50 | avg 0.25s/epoch | total 12.6s | val_loss: 0.281768
#   RNN  Run 4: 5/50 epochs | EARLY STOP | best@2 | avg 0.22s/epoch | total 1.1s | val_loss: 0.695996
#   LSTM Run 4: 43/50 epochs | EARLY STOP | best@40 | avg 0.25s/epoch | total 10.8s | val_loss: 0.028734
#   RNN  Run 5: 4/50 epochs | EARLY STOP | best@1 | avg 0.21s/epoch | total 0.9s | val_loss: 0.694980
#   LSTM Run 5: 27/50 epochs | EARLY STOP | best@24 | avg 0.25s/epoch | total 6.7s | val_loss: 0.261049
#   >> RNN  avg accuracy: 0.4991
#   >> LSTM avg accuracy: 0.8305
#
# ============================================================
# DELAY 17 - 5 runs
# ============================================================
#   RNN  Run 1: 8/50 epochs | EARLY STOP | best@5 | avg 0.23s/epoch | total 1.8s | val_loss: 0.694125
#   LSTM Run 1: 8/50 epochs | EARLY STOP | best@5 | avg 0.28s/epoch | total 2.2s | val_loss: 0.693153
#   RNN  Run 2: 6/50 epochs | EARLY STOP | best@3 | avg 0.23s/epoch | total 1.4s | val_loss: 0.694393
#   LSTM Run 2: 5/50 epochs | EARLY STOP | best@2 | avg 0.28s/epoch | total 1.4s | val_loss: 0.693158
#   RNN  Run 3: 8/50 epochs | EARLY STOP | best@5 | avg 0.23s/epoch | total 1.8s | val_loss: 0.694182
#   LSTM Run 3: 4/50 epochs | EARLY STOP | best@1 | avg 0.29s/epoch | total 1.2s | val_loss: 0.693175
#   RNN  Run 4: 6/50 epochs | EARLY STOP | best@3 | avg 0.22s/epoch | total 1.3s | val_loss: 0.694344
#   LSTM Run 4: 22/50 epochs | EARLY STOP | best@19 | avg 0.28s/epoch | total 6.2s | val_loss: 0.571992
#   RNN  Run 5: 4/50 epochs | EARLY STOP | best@1 | avg 0.22s/epoch | total 0.9s | val_loss: 0.694713
#   LSTM Run 5: 13/50 epochs | EARLY STOP | best@10 | avg 0.28s/epoch | total 3.7s | val_loss: 0.693152
#   >> RNN  avg accuracy: 0.4997
#   >> LSTM avg accuracy: 0.5173
#
# ============================================================
# DELAY 21 - 5 runs
# ============================================================
#   RNN  Run 1: 4/50 epochs | EARLY STOP | best@1 | avg 0.23s/epoch | total 0.9s | val_loss: 0.694169
#   LSTM Run 1: 8/50 epochs | EARLY STOP | best@5 | avg 0.32s/epoch | total 2.6s | val_loss: 0.673704
#   RNN  Run 2: 7/50 epochs | EARLY STOP | best@4 | avg 0.23s/epoch | total 1.6s | val_loss: 0.693868
#   LSTM Run 2: 9/50 epochs | EARLY STOP | best@6 | avg 0.32s/epoch | total 2.9s | val_loss: 0.688470
#   RNN  Run 3: 5/50 epochs | EARLY STOP | best@2 | avg 0.22s/epoch | total 1.1s | val_loss: 0.694578
#   LSTM Run 3: 5/50 epochs | EARLY STOP | best@2 | avg 0.32s/epoch | total 1.6s | val_loss: 0.693177
#   RNN  Run 4: 5/50 epochs | EARLY STOP | best@2 | avg 0.23s/epoch | total 1.1s | val_loss: 0.693736
#   LSTM Run 4: 15/50 epochs | EARLY STOP | best@12 | avg 0.32s/epoch | total 4.8s | val_loss: 0.608426
#   RNN  Run 5: 9/50 epochs | EARLY STOP | best@6 | avg 0.23s/epoch | total 2.1s | val_loss: 0.694566
#   LSTM Run 5: 41/50 epochs | EARLY STOP | best@38 | avg 0.32s/epoch | total 13.2s | val_loss: 0.560476
#   >> RNN  avg accuracy: 0.4992
#   >> LSTM avg accuracy: 0.5459
#
# ============================================================
# DELAY 25 - 5 runs
# ============================================================
#   RNN  Run 1: 6/50 epochs | EARLY STOP | best@3 | avg 0.24s/epoch | total 1.4s | val_loss: 0.693851
#   LSTM Run 1: 7/50 epochs | EARLY STOP | best@4 | avg 0.36s/epoch | total 2.5s | val_loss: 0.693152
#   RNN  Run 2: 9/50 epochs | EARLY STOP | best@6 | avg 0.24s/epoch | total 2.2s | val_loss: 0.694352
#   LSTM Run 2: 4/50 epochs | EARLY STOP | best@1 | avg 0.36s/epoch | total 1.4s | val_loss: 0.693154
#   RNN  Run 3: 8/50 epochs | EARLY STOP | best@5 | avg 0.24s/epoch | total 1.9s | val_loss: 0.693935
#   LSTM Run 3: 8/50 epochs | EARLY STOP | best@5 | avg 0.36s/epoch | total 2.9s | val_loss: 0.693160
#   RNN  Run 4: 7/50 epochs | EARLY STOP | best@4 | avg 0.24s/epoch | total 1.7s | val_loss: 0.693834
#   LSTM Run 4: 4/50 epochs | EARLY STOP | best@1 | avg 0.36s/epoch | total 1.4s | val_loss: 0.693166
#   RNN  Run 5: 8/50 epochs | EARLY STOP | best@5 | avg 0.24s/epoch | total 1.9s | val_loss: 0.693657
#   LSTM Run 5: 7/50 epochs | EARLY STOP | best@4 | avg 0.36s/epoch | total 2.5s | val_loss: 0.693148
#   >> RNN  avg accuracy: 0.5003
#   >> LSTM avg accuracy: 0.5000
#
# ============================================================
# DELAY 29 - 5 runs
# ============================================================
#   RNN  Run 1: 6/50 epochs | EARLY STOP | best@3 | avg 0.26s/epoch | total 1.5s | val_loss: 0.694237
#   LSTM Run 1: 7/50 epochs | EARLY STOP | best@4 | avg 0.40s/epoch | total 2.8s | val_loss: 0.693168
#   RNN  Run 2: 9/50 epochs | EARLY STOP | best@6 | avg 0.26s/epoch | total 2.3s | val_loss: 0.693642
#   LSTM Run 2: 5/50 epochs | EARLY STOP | best@2 | avg 0.40s/epoch | total 2.0s | val_loss: 0.693163
#   RNN  Run 3: 4/50 epochs | EARLY STOP | best@1 | avg 0.27s/epoch | total 1.1s | val_loss: 0.694627
#   LSTM Run 3: 7/50 epochs | EARLY STOP | best@4 | avg 0.40s/epoch | total 2.8s | val_loss: 0.693182
#   RNN  Run 4: 4/50 epochs | EARLY STOP | best@1 | avg 0.26s/epoch | total 1.0s | val_loss: 0.694908
#   LSTM Run 4: 5/50 epochs | EARLY STOP | best@2 | avg 0.40s/epoch | total 2.0s | val_loss: 0.693187
#   RNN  Run 5: 4/50 epochs | EARLY STOP | best@1 | avg 0.25s/epoch | total 1.0s | val_loss: 0.694009
#   LSTM Run 5: 4/50 epochs | EARLY STOP | best@1 | avg 0.40s/epoch | total 1.6s | val_loss: 0.693164
#   >> RNN  avg accuracy: 0.5000
#   >> LSTM avg accuracy: 0.4993
