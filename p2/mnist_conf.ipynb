# %%
from itertools import product
import matplotlib.pyplot as plt
import seaborn as sns
import time
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import os
# Out:
# 2025-11-01 22:33:07.195471: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-01 22:33:08.085578: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-01 22:33:09.940537: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %% [markdown]
# # 1. Carga y exploración de datos

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

print(f"Datos de entrenamiento: {x_train.shape}")
print(f"Datos de test:          {x_test.shape}")
print(f"Etiquetas train:        {y_train.shape}")
print(f"Etiquetas test:         {y_test.shape}")
print(f"\nPrimeras 10 etiquetas:  {y_train[:10]}")
print(f"Rango original:         [{x_train[0].min()}, {x_train[0].max()}]")
# Out:
# Datos de entrenamiento: (60000, 28, 28)
# Datos de test:          (10000, 28, 28)
# Etiquetas train:        (60000,)
# Etiquetas test:         (10000,)
#
# Primeras 10 etiquetas:  [5 0 4 1 9 2 1 3 1 4]
# Rango original:         [0, 255]

# %% [markdown]
# # 2. Preprocesamiento

# %%
# Normalización
x_train = x_train / 255.0
x_test = x_test / 255.0

print(f"Rango normalizado: [{x_train[0].min():.2f}, {x_train[0].max():.2f}]")
# Out:
# Rango normalizado: [0.00, 1.00]

# %% [markdown]
# # 3. Configuraciones a evaluar

# %%
# Valores posibles para cada parámetro
param_values = {
    'hidden_neurons': [128, 256, 512],
    'epochs': [10, 15, 20],
    'loss': ['sparse_categorical_crossentropy'],
    'batch_size': [128, 256],
    'lr': [0.001, 0.01],
    'validation_split': [0.1, 0.2]
}

param_names = list(param_values.keys())
param_combinations = list(product(*param_values.values()))

configurations = []
for i, combination in enumerate(param_combinations, 1):
    config = {'name': f'Config_{i}'}
    for param_name, param_value in zip(param_names, combination):
        config[param_name] = param_value
    configurations.append(config)

for config in configurations:
    print(f"{config['name']:>10} | "
          f"neurons={config['hidden_neurons']:>3} | "
          f"epochs={config['epochs']:>2} | "
          f"batch={config['batch_size']:>3} | "
          f"lr={config['lr']:.4f} | "
          f"val_split={config['validation_split']:.1f}")
# Out:
#   Config_1 | neurons=128 | epochs=10 | batch=128 | lr=0.0010 | val_split=0.1
#   Config_2 | neurons=128 | epochs=10 | batch=128 | lr=0.0010 | val_split=0.2
#   Config_3 | neurons=128 | epochs=10 | batch=128 | lr=0.0100 | val_split=0.1
#   Config_4 | neurons=128 | epochs=10 | batch=128 | lr=0.0100 | val_split=0.2
#   Config_5 | neurons=128 | epochs=10 | batch=256 | lr=0.0010 | val_split=0.1
#   Config_6 | neurons=128 | epochs=10 | batch=256 | lr=0.0010 | val_split=0.2
#   Config_7 | neurons=128 | epochs=10 | batch=256 | lr=0.0100 | val_split=0.1
#   Config_8 | neurons=128 | epochs=10 | batch=256 | lr=0.0100 | val_split=0.2
#   Config_9 | neurons=128 | epochs=15 | batch=128 | lr=0.0010 | val_split=0.1
#  Config_10 | neurons=128 | epochs=15 | batch=128 | lr=0.0010 | val_split=0.2
#  Config_11 | neurons=128 | epochs=15 | batch=128 | lr=0.0100 | val_split=0.1
#  Config_12 | neurons=128 | epochs=15 | batch=128 | lr=0.0100 | val_split=0.2
#  Config_13 | neurons=128 | epochs=15 | batch=256 | lr=0.0010 | val_split=0.1
#  Config_14 | neurons=128 | epochs=15 | batch=256 | lr=0.0010 | val_split=0.2
#  Config_15 | neurons=128 | epochs=15 | batch=256 | lr=0.0100 | val_split=0.1
#  Config_16 | neurons=128 | epochs=15 | batch=256 | lr=0.0100 | val_split=0.2
#  Config_17 | neurons=128 | epochs=20 | batch=128 | lr=0.0010 | val_split=0.1
#  Config_18 | neurons=128 | epochs=20 | batch=128 | lr=0.0010 | val_split=0.2
#  Config_19 | neurons=128 | epochs=20 | batch=128 | lr=0.0100 | val_split=0.1
#  Config_20 | neurons=128 | epochs=20 | batch=128 | lr=0.0100 | val_split=0.2
#  Config_21 | neurons=128 | epochs=20 | batch=256 | lr=0.0010 | val_split=0.1
#  Config_22 | neurons=128 | epochs=20 | batch=256 | lr=0.0010 | val_split=0.2
#  Config_23 | neurons=128 | epochs=20 | batch=256 | lr=0.0100 | val_split=0.1
#  Config_24 | neurons=128 | epochs=20 | batch=256 | lr=0.0100 | val_split=0.2
#  Config_25 | neurons=256 | epochs=10 | batch=128 | lr=0.0010 | val_split=0.1
#  Config_26 | neurons=256 | epochs=10 | batch=128 | lr=0.0010 | val_split=0.2
#  Config_27 | neurons=256 | epochs=10 | batch=128 | lr=0.0100 | val_split=0.1
#  Config_28 | neurons=256 | epochs=10 | batch=128 | lr=0.0100 | val_split=0.2
#  Config_29 | neurons=256 | epochs=10 | batch=256 | lr=0.0010 | val_split=0.1
#  Config_30 | neurons=256 | epochs=10 | batch=256 | lr=0.0010 | val_split=0.2
#  Config_31 | neurons=256 | epochs=10 | batch=256 | lr=0.0100 | val_split=0.1
#  Config_32 | neurons=256 | epochs=10 | batch=256 | lr=0.0100 | val_split=0.2
#  Config_33 | neurons=256 | epochs=15 | batch=128 | lr=0.0010 | val_split=0.1
#  Config_34 | neurons=256 | epochs=15 | batch=128 | lr=0.0010 | val_split=0.2
#  Config_35 | neurons=256 | epochs=15 | batch=128 | lr=0.0100 | val_split=0.1
#  Config_36 | neurons=256 | epochs=15 | batch=128 | lr=0.0100 | val_split=0.2
#  Config_37 | neurons=256 | epochs=15 | batch=256 | lr=0.0010 | val_split=0.1
#  Config_38 | neurons=256 | epochs=15 | batch=256 | lr=0.0010 | val_split=0.2
#  Config_39 | neurons=256 | epochs=15 | batch=256 | lr=0.0100 | val_split=0.1
#  Config_40 | neurons=256 | epochs=15 | batch=256 | lr=0.0100 | val_split=0.2
#  Config_41 | neurons=256 | epochs=20 | batch=128 | lr=0.0010 | val_split=0.1
#  Config_42 | neurons=256 | epochs=20 | batch=128 | lr=0.0010 | val_split=0.2
#  Config_43 | neurons=256 | epochs=20 | batch=128 | lr=0.0100 | val_split=0.1
#  Config_44 | neurons=256 | epochs=20 | batch=128 | lr=0.0100 | val_split=0.2
#  Config_45 | neurons=256 | epochs=20 | batch=256 | lr=0.0010 | val_split=0.1
#  Config_46 | neurons=256 | epochs=20 | batch=256 | lr=0.0010 | val_split=0.2
#  Config_47 | neurons=256 | epochs=20 | batch=256 | lr=0.0100 | val_split=0.1
#  Config_48 | neurons=256 | epochs=20 | batch=256 | lr=0.0100 | val_split=0.2
#  Config_49 | neurons=512 | epochs=10 | batch=128 | lr=0.0010 | val_split=0.1
#  Config_50 | neurons=512 | epochs=10 | batch=128 | lr=0.0010 | val_split=0.2
#  Config_51 | neurons=512 | epochs=10 | batch=128 | lr=0.0100 | val_split=0.1
#  Config_52 | neurons=512 | epochs=10 | batch=128 | lr=0.0100 | val_split=0.2
#  Config_53 | neurons=512 | epochs=10 | batch=256 | lr=0.0010 | val_split=0.1
#  Config_54 | neurons=512 | epochs=10 | batch=256 | lr=0.0010 | val_split=0.2
#  Config_55 | neurons=512 | epochs=10 | batch=256 | lr=0.0100 | val_split=0.1
#  Config_56 | neurons=512 | epochs=10 | batch=256 | lr=0.0100 | val_split=0.2
#  Config_57 | neurons=512 | epochs=15 | batch=128 | lr=0.0010 | val_split=0.1
#  Config_58 | neurons=512 | epochs=15 | batch=128 | lr=0.0010 | val_split=0.2
#  Config_59 | neurons=512 | epochs=15 | batch=128 | lr=0.0100 | val_split=0.1
#  Config_60 | neurons=512 | epochs=15 | batch=128 | lr=0.0100 | val_split=0.2
#  Config_61 | neurons=512 | epochs=15 | batch=256 | lr=0.0010 | val_split=0.1
#  Config_62 | neurons=512 | epochs=15 | batch=256 | lr=0.0010 | val_split=0.2
#  Config_63 | neurons=512 | epochs=15 | batch=256 | lr=0.0100 | val_split=0.1
#  Config_64 | neurons=512 | epochs=15 | batch=256 | lr=0.0100 | val_split=0.2
#  Config_65 | neurons=512 | epochs=20 | batch=128 | lr=0.0010 | val_split=0.1
#  Config_66 | neurons=512 | epochs=20 | batch=128 | lr=0.0010 | val_split=0.2
#  Config_67 | neurons=512 | epochs=20 | batch=128 | lr=0.0100 | val_split=0.1
#  Config_68 | neurons=512 | epochs=20 | batch=128 | lr=0.0100 | val_split=0.2
#  Config_69 | neurons=512 | epochs=20 | batch=256 | lr=0.0010 | val_split=0.1
#  Config_70 | neurons=512 | epochs=20 | batch=256 | lr=0.0010 | val_split=0.2
#  Config_71 | neurons=512 | epochs=20 | batch=256 | lr=0.0100 | val_split=0.1
#  Config_72 | neurons=512 | epochs=20 | batch=256 | lr=0.0100 | val_split=0.2

# %% [markdown]
# # 4. Función para crear modelos

# %%
def create_model(hidden_neurons: int = 128) -> tf.keras.models.Sequential:
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
    model.add(tf.keras.layers.Dense(hidden_neurons, activation='relu'))
    model.add(tf.keras.layers.Dense(10, activation='softmax'))

    return model

# %% [markdown]
# # 5. Función de evaluación completa

# %%
def evaluate_model(model: tf.keras.models.Sequential, x_test: np.ndarray, y_test: np.ndarray) -> dict:
    results = {}

    # Accuracy y loss en test
    loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
    print(f"Loss: {loss:.4f}, Accuracy: {accuracy:.4f}")

    # Predicciones y número de errores
    y_pred = np.argmax(model.predict(x_test, verbose=0), axis=1)

    errors = np.sum(y_pred != y_test)

    print(f"Errors:  {errors}/{len(y_test)} ({errors/len(y_test)*100:.2f}%)")

    # Matrices de confusión
    cm = confusion_matrix(y_test, y_pred)

    # Guardar resultados
    results['loss'] = loss
    results['accuracy'] = accuracy
    results['errors'] = errors
    results['cm'] = cm
    results['predictions'] = y_pred

    return results

# %% [markdown]
# # 6. Entrenamiento de todas las configuraciones

# %%
all_results = {}
all_histories = {}

for config in configurations:
    name = config['name']
    print(f"\n{'▶'*3} Configuración: {name}")
    print(f"    Neuronas capa oculta: {config['hidden_neurons']}")
    print(f"    Épocas: {config['epochs']}")
    print(f"    Loss: {config['loss']}")
    print(f"    Batch size: {config['batch_size']}")
    print(f"    Learning rate: {config['lr']}")
    print(f"    Validation split: {config['validation_split']}")
    print(f"    Optimizer: Adam (fijo)")

    model = create_model(hidden_neurons=int(config['hidden_neurons']))
    optimizer = tf.keras.optimizers.Adam(learning_rate=config['lr'])

    model.compile(
        optimizer=optimizer,
        loss=config['loss'],
        metrics=['accuracy']
    )

    # Entrenar y medir tiempo
    start_time = time.time()
    history = model.fit(
        x_train, y_train,
        epochs=config['epochs'],
        batch_size=config['batch_size'],
        validation_split=config['validation_split'],
        verbose=1
    )
    elapsed_time = time.time() - start_time

    print(f"\n⏱️  Tiempo de entrenamiento: {elapsed_time:.2f} segundos")

    val_loss = history.history['val_loss'][-1]
    val_accuracy = history.history['val_accuracy'][-1]

    # Guardar
    all_histories[name] = history
    all_results[name] = {
        'config': config,
        'model': model,
        'training_time': elapsed_time,
        'val_loss': val_loss,
        'val_accuracy': val_accuracy
    }
# Out:
# ▶▶▶ Configuración: Config_1
#     Neuronas capa oculta: 128
#     Épocas: 10
#     Loss: sparse_categorical_crossentropy
#     Batch size: 128
#     Learning rate: 0.001
#     Validation split: 0.1
#     Optimizer: Adam (fijo)
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-11-01 22:33:10.798882: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8930 - loss: 0.3894 - val_accuracy: 0.9523 - val_loss: 0.1756
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9481 - loss: 0.1806 - val_accuracy: 0.9640 - val_loss: 0.1295
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9619 - loss: 0.1317 - val_accuracy: 0.9710 - val_loss: 0.1091
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9716 - loss: 0.1005 - val_accuracy: 0.9718 - val_loss: 0.1007
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9767 - loss: 0.0822 - val_accuracy: 0.9740 - val_loss: 0.0834
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9805 - loss: 0.0678 - val_accuracy: 0.9755 - val_loss: 0.0817
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9837 - loss: 0.0563 - val_accuracy: 0.9757 - val_loss: 0.0816
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9869 - loss: 0.0471 - val_accuracy: 0.9742 - val_loss: 0.0826
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9887 - loss: 0.0399 - val_accuracy: 0.9773 - val_loss: 0.0771
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9907 - loss: 0.0336 - val_accuracy: 0.9773 - val_loss: 0.0773
#
# ⏱️  Tiempo de entrenamiento: 11.16 segundos
#
# ▶▶▶ Configuración: Config_2
#     Neuronas capa oculta: 128
#     Épocas: 10
#     Loss: sparse_categorical_crossentropy
#     Batch size: 128
#     Learning rate: 0.001
#     Validation split: 0.2
#     Optimizer: Adam (fijo)
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8923 - loss: 0.3925 - val_accuracy: 0.9371 - val_loss: 0.2244
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9458 - loss: 0.1902 - val_accuracy: 0.9551 - val_loss: 0.1600
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9606 - loss: 0.1383 - val_accuracy: 0.9613 - val_loss: 0.1367
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9699 - loss: 0.1065 - val_accuracy: 0.9662 - val_loss: 0.1175
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9754 - loss: 0.0858 - val_accuracy: 0.9697 - val_loss: 0.1053
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9797 - loss: 0.0709 - val_accuracy: 0.9709 - val_loss: 0.0976
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9828 - loss: 0.0603 - val_accuracy: 0.9734 - val_loss: 0.0940
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9858 - loss: 0.0506 - val_accuracy: 0.9721 - val_loss: 0.0917
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9880 - loss: 0.0433 - val_accuracy: 0.9746 - val_loss: 0.0854
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9904 - loss: 0.0362 - val_accuracy: 0.9742 - val_loss: 0.0840
#
# ⏱️  Tiempo de entrenamiento: 10.56 segundos
#
# ▶▶▶ Configuración: Config_3
#     Neuronas capa oculta: 128
#     Épocas: 10
#     Loss: sparse_categorical_crossentropy
#     Batch size: 128
#     Learning rate: 0.01
#     Validation split: 0.1
#     Optimizer: Adam (fijo)
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9307 - loss: 0.2299 - val_accuracy: 0.9627 - val_loss: 0.1278
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9649 - loss: 0.1142 - val_accuracy: 0.9658 - val_loss: 0.1226
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9713 - loss: 0.0926 - val_accuracy: 0.9703 - val_loss: 0.1077
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9767 - loss: 0.0769 - val_accuracy: 0.9725 - val_loss: 0.1199
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9794 - loss: 0.0673 - val_accuracy: 0.9720 - val_loss: 0.1165
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9817 - loss: 0.0609 - val_accuracy: 0.9745 - val_loss: 0.1126
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9829 - loss: 0.0549 - val_accuracy: 0.9718 - val_loss: 0.1190
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9825 - loss: 0.0588 - val_accuracy: 0.9735 - val_loss: 0.1436
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9847 - loss: 0.0511 - val_accuracy: 0.9742 - val_loss: 0.1344
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9855 - loss: 0.0510 - val_accuracy: 0.9772 - val_loss: 0.1352
#
# ⏱️  Tiempo de entrenamiento: 11.24 segundos
#
# ▶▶▶ Configuración: Config_4
#     Neuronas capa oculta: 128
#     Épocas: 10
#     Loss: sparse_categorical_crossentropy
#     Batch size: 128
#     Learning rate: 0.01
#     Validation split: 0.2
#     Optimizer: Adam (fijo)
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9298 - loss: 0.2328 - val_accuracy: 0.9622 - val_loss: 0.1215
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9645 - loss: 0.1175 - val_accuracy: 0.9636 - val_loss: 0.1283
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9728 - loss: 0.0881 - val_accuracy: 0.9600 - val_loss: 0.1440
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9769 - loss: 0.0735 - val_accuracy: 0.9632 - val_loss: 0.1498
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9793 - loss: 0.0686 - val_accuracy: 0.9645 - val_loss: 0.1427
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9810 - loss: 0.0615 - val_accuracy: 0.9720 - val_loss: 0.1258
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9833 - loss: 0.0535 - val_accuracy: 0.9667 - val_loss: 0.1770
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9816 - loss: 0.0629 - val_accuracy: 0.9592 - val_loss: 0.1921
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9833 - loss: 0.0587 - val_accuracy: 0.9623 - val_loss: 0.2249
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9854 - loss: 0.0538 - val_accuracy: 0.9689 - val_loss: 0.1884
#
# ⏱️  Tiempo de entrenamiento: 10.91 segundos
#
# ▶▶▶ Configuración: Config_5
#     Neuronas capa oculta: 128
#     Épocas: 10
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.001
#     Validation split: 0.1
#     Optimizer: Adam (fijo)
# Epoch 1/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8713 - loss: 0.4724 - val_accuracy: 0.9438 - val_loss: 0.2109
# Epoch 2/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9379 - loss: 0.2190 - val_accuracy: 0.9603 - val_loss: 0.1523
# Epoch 3/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9533 - loss: 0.1650 - val_accuracy: 0.9662 - val_loss: 0.1235
# Epoch 4/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9613 - loss: 0.1338 - val_accuracy: 0.9698 - val_loss: 0.1100
# Epoch 5/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9683 - loss: 0.1107 - val_accuracy: 0.9722 - val_loss: 0.1006
# Epoch 6/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9732 - loss: 0.0944 - val_accuracy: 0.9720 - val_loss: 0.0945
# Epoch 7/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9768 - loss: 0.0808 - val_accuracy: 0.9737 - val_loss: 0.0929
# Epoch 8/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9794 - loss: 0.0703 - val_accuracy: 0.9758 - val_loss: 0.0850
# Epoch 9/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9830 - loss: 0.0611 - val_accuracy: 0.9758 - val_loss: 0.0840
# Epoch 10/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9849 - loss: 0.0546 - val_accuracy: 0.9750 - val_loss: 0.0807
#
# ⏱️  Tiempo de entrenamiento: 7.36 segundos
#
# ▶▶▶ Configuración: Config_6
#     Neuronas capa oculta: 128
#     Épocas: 10
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.001
#     Validation split: 0.2
#     Optimizer: Adam (fijo)
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8665 - loss: 0.4954 - val_accuracy: 0.9331 - val_loss: 0.2423
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9368 - loss: 0.2210 - val_accuracy: 0.9492 - val_loss: 0.1858
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9525 - loss: 0.1685 - val_accuracy: 0.9567 - val_loss: 0.1567
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9619 - loss: 0.1354 - val_accuracy: 0.9622 - val_loss: 0.1342
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9685 - loss: 0.1130 - val_accuracy: 0.9640 - val_loss: 0.1250
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9730 - loss: 0.0966 - val_accuracy: 0.9678 - val_loss: 0.1146
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9768 - loss: 0.0829 - val_accuracy: 0.9691 - val_loss: 0.1087
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9804 - loss: 0.0720 - val_accuracy: 0.9702 - val_loss: 0.1006
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9826 - loss: 0.0636 - val_accuracy: 0.9714 - val_loss: 0.1008
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9847 - loss: 0.0565 - val_accuracy: 0.9718 - val_loss: 0.0925
#
# ⏱️  Tiempo de entrenamiento: 6.97 segundos
#
# ▶▶▶ Configuración: Config_7
#     Neuronas capa oculta: 128
#     Épocas: 10
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.01
#     Validation split: 0.1
#     Optimizer: Adam (fijo)
# Epoch 1/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9159 - loss: 0.2783 - val_accuracy: 0.9655 - val_loss: 0.1118
# Epoch 2/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9660 - loss: 0.1118 - val_accuracy: 0.9690 - val_loss: 0.0989
# Epoch 3/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9745 - loss: 0.0805 - val_accuracy: 0.9765 - val_loss: 0.0814
# Epoch 4/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9809 - loss: 0.0623 - val_accuracy: 0.9732 - val_loss: 0.0874
# Epoch 5/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9839 - loss: 0.0511 - val_accuracy: 0.9718 - val_loss: 0.1056
# Epoch 6/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9836 - loss: 0.0513 - val_accuracy: 0.9748 - val_loss: 0.1091
# Epoch 7/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9883 - loss: 0.0375 - val_accuracy: 0.9762 - val_loss: 0.1058
# Epoch 8/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9868 - loss: 0.0405 - val_accuracy: 0.9765 - val_loss: 0.1120
# Epoch 9/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9889 - loss: 0.0345 - val_accuracy: 0.9752 - val_loss: 0.1315
# Epoch 10/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9891 - loss: 0.0337 - val_accuracy: 0.9755 - val_loss: 0.1217
#
# ⏱️  Tiempo de entrenamiento: 7.12 segundos
#
# ▶▶▶ Configuración: Config_8
#     Neuronas capa oculta: 128
#     Épocas: 10
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.01
#     Validation split: 0.2
#     Optimizer: Adam (fijo)
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9194 - loss: 0.2655 - val_accuracy: 0.9628 - val_loss: 0.1288
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9657 - loss: 0.1123 - val_accuracy: 0.9663 - val_loss: 0.1192
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9749 - loss: 0.0795 - val_accuracy: 0.9687 - val_loss: 0.1036
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9804 - loss: 0.0592 - val_accuracy: 0.9715 - val_loss: 0.0975
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9840 - loss: 0.0473 - val_accuracy: 0.9678 - val_loss: 0.1269
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9855 - loss: 0.0443 - val_accuracy: 0.9712 - val_loss: 0.1079
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9871 - loss: 0.0394 - val_accuracy: 0.9709 - val_loss: 0.1205
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9875 - loss: 0.0386 - val_accuracy: 0.9716 - val_loss: 0.1257
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9904 - loss: 0.0295 - val_accuracy: 0.9679 - val_loss: 0.1490
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9888 - loss: 0.0333 - val_accuracy: 0.9707 - val_loss: 0.1367
#
# ⏱️  Tiempo de entrenamiento: 7.16 segundos
#
# ▶▶▶ Configuración: Config_9
#     Neuronas capa oculta: 128
#     Épocas: 15
#     Loss: sparse_categorical_crossentropy
#     Batch size: 128
#     Learning rate: 0.001
#     Validation split: 0.1
#     Optimizer: Adam (fijo)
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8941 - loss: 0.3777 - val_accuracy: 0.9578 - val_loss: 0.1684
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9518 - loss: 0.1692 - val_accuracy: 0.9688 - val_loss: 0.1216
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9656 - loss: 0.1202 - val_accuracy: 0.9707 - val_loss: 0.1054
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9730 - loss: 0.0932 - val_accuracy: 0.9737 - val_loss: 0.0895
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9784 - loss: 0.0750 - val_accuracy: 0.9753 - val_loss: 0.0875
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9822 - loss: 0.0618 - val_accuracy: 0.9770 - val_loss: 0.0806
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9856 - loss: 0.0515 - val_accuracy: 0.9777 - val_loss: 0.0807
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9875 - loss: 0.0432 - val_accuracy: 0.9782 - val_loss: 0.0772
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9902 - loss: 0.0360 - val_accuracy: 0.9787 - val_loss: 0.0805
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9919 - loss: 0.0311 - val_accuracy: 0.9805 - val_loss: 0.0735
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9933 - loss: 0.0263 - val_accuracy: 0.9800 - val_loss: 0.0745
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9947 - loss: 0.0223 - val_accuracy: 0.9805 - val_loss: 0.0774
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9957 - loss: 0.0190 - val_accuracy: 0.9795 - val_loss: 0.0782
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9961 - loss: 0.0167 - val_accuracy: 0.9792 - val_loss: 0.0827
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9973 - loss: 0.0135 - val_accuracy: 0.9793 - val_loss: 0.0828
#
# ⏱️  Tiempo de entrenamiento: 16.70 segundos
#
# ▶▶▶ Configuración: Config_10
#     Neuronas capa oculta: 128
#     Épocas: 15
#     Loss: sparse_categorical_crossentropy
#     Batch size: 128
#     Learning rate: 0.001
#     Validation split: 0.2
#     Optimizer: Adam (fijo)
# Epoch 1/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8914 - loss: 0.3973 - val_accuracy: 0.9405 - val_loss: 0.2069
# Epoch 2/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9471 - loss: 0.1856 - val_accuracy: 0.9567 - val_loss: 0.1551
# Epoch 3/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9612 - loss: 0.1364 - val_accuracy: 0.9606 - val_loss: 0.1385
# Epoch 4/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9692 - loss: 0.1064 - val_accuracy: 0.9642 - val_loss: 0.1227
# Epoch 5/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9755 - loss: 0.0861 - val_accuracy: 0.9684 - val_loss: 0.1085
# Epoch 6/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9793 - loss: 0.0720 - val_accuracy: 0.9693 - val_loss: 0.1002
# Epoch 7/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9831 - loss: 0.0604 - val_accuracy: 0.9727 - val_loss: 0.0937
# Epoch 8/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9859 - loss: 0.0502 - val_accuracy: 0.9735 - val_loss: 0.0899
# Epoch 9/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9880 - loss: 0.0424 - val_accuracy: 0.9718 - val_loss: 0.0895
# Epoch 10/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9903 - loss: 0.0359 - val_accuracy: 0.9744 - val_loss: 0.0860
# Epoch 11/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9914 - loss: 0.0321 - val_accuracy: 0.9762 - val_loss: 0.0857
# Epoch 12/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9937 - loss: 0.0253 - val_accuracy: 0.9735 - val_loss: 0.0884
# Epoch 13/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9945 - loss: 0.0220 - val_accuracy: 0.9744 - val_loss: 0.0879
# Epoch 14/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9958 - loss: 0.0194 - val_accuracy: 0.9745 - val_loss: 0.0922
# Epoch 15/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9966 - loss: 0.0159 - val_accuracy: 0.9736 - val_loss: 0.0900
#
# ⏱️  Tiempo de entrenamiento: 16.16 segundos
#
# ▶▶▶ Configuración: Config_11
#     Neuronas capa oculta: 128
#     Épocas: 15
#     Loss: sparse_categorical_crossentropy
#     Batch size: 128
#     Learning rate: 0.01
#     Validation split: 0.1
#     Optimizer: Adam (fijo)
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9302 - loss: 0.2256 - val_accuracy: 0.9657 - val_loss: 0.1108
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9662 - loss: 0.1127 - val_accuracy: 0.9680 - val_loss: 0.1116
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9715 - loss: 0.0903 - val_accuracy: 0.9673 - val_loss: 0.1274
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9772 - loss: 0.0764 - val_accuracy: 0.9710 - val_loss: 0.1028
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9791 - loss: 0.0692 - val_accuracy: 0.9732 - val_loss: 0.1106
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9812 - loss: 0.0627 - val_accuracy: 0.9768 - val_loss: 0.1077
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9825 - loss: 0.0607 - val_accuracy: 0.9718 - val_loss: 0.1252
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9834 - loss: 0.0560 - val_accuracy: 0.9723 - val_loss: 0.1501
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9838 - loss: 0.0571 - val_accuracy: 0.9745 - val_loss: 0.1441
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9862 - loss: 0.0476 - val_accuracy: 0.9722 - val_loss: 0.1450
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9881 - loss: 0.0412 - val_accuracy: 0.9742 - val_loss: 0.1545
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9865 - loss: 0.0510 - val_accuracy: 0.9747 - val_loss: 0.1719
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9885 - loss: 0.0431 - val_accuracy: 0.9748 - val_loss: 0.1671
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9891 - loss: 0.0379 - val_accuracy: 0.9703 - val_loss: 0.2090
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9878 - loss: 0.0501 - val_accuracy: 0.9692 - val_loss: 0.2127
#
# ⏱️  Tiempo de entrenamiento: 16.07 segundos
#
# ▶▶▶ Configuración: Config_12
#     Neuronas capa oculta: 128
#     Épocas: 15
#     Loss: sparse_categorical_crossentropy
#     Batch size: 128
#     Learning rate: 0.01
#     Validation split: 0.2
#     Optimizer: Adam (fijo)
# Epoch 1/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9260 - loss: 0.2412 - val_accuracy: 0.9607 - val_loss: 0.1337
# Epoch 2/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9640 - loss: 0.1182 - val_accuracy: 0.9637 - val_loss: 0.1253
# Epoch 3/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9727 - loss: 0.0887 - val_accuracy: 0.9668 - val_loss: 0.1235
# Epoch 4/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9760 - loss: 0.0782 - val_accuracy: 0.9666 - val_loss: 0.1337
# Epoch 5/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9791 - loss: 0.0688 - val_accuracy: 0.9704 - val_loss: 0.1292
# Epoch 6/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9812 - loss: 0.0619 - val_accuracy: 0.9658 - val_loss: 0.1552
# Epoch 7/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9836 - loss: 0.0528 - val_accuracy: 0.9668 - val_loss: 0.1572
# Epoch 8/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9826 - loss: 0.0578 - val_accuracy: 0.9694 - val_loss: 0.1645
# Epoch 9/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9859 - loss: 0.0481 - val_accuracy: 0.9678 - val_loss: 0.1802
# Epoch 10/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9849 - loss: 0.0549 - val_accuracy: 0.9690 - val_loss: 0.1798
# Epoch 11/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9878 - loss: 0.0423 - val_accuracy: 0.9653 - val_loss: 0.1988
# Epoch 12/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9880 - loss: 0.0435 - val_accuracy: 0.9704 - val_loss: 0.1892
# Epoch 13/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9894 - loss: 0.0400 - val_accuracy: 0.9674 - val_loss: 0.2340
# Epoch 14/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9886 - loss: 0.0432 - val_accuracy: 0.9648 - val_loss: 0.2485
# Epoch 15/15
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9892 - loss: 0.0429 - val_accuracy: 0.9675 - val_loss: 0.2279
#
# ⏱️  Tiempo de entrenamiento: 15.47 segundos
#
# ▶▶▶ Configuración: Config_13
#     Neuronas capa oculta: 128
#     Épocas: 15
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.001
#     Validation split: 0.1
#     Optimizer: Adam (fijo)
# Epoch 1/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8742 - loss: 0.4685 - val_accuracy: 0.9428 - val_loss: 0.2074
# Epoch 2/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9364 - loss: 0.2231 - val_accuracy: 0.9592 - val_loss: 0.1529
# Epoch 3/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9523 - loss: 0.1684 - val_accuracy: 0.9655 - val_loss: 0.1247
# Epoch 4/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9619 - loss: 0.1358 - val_accuracy: 0.9680 - val_loss: 0.1135
# Epoch 5/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9680 - loss: 0.1121 - val_accuracy: 0.9708 - val_loss: 0.1035
# Epoch 6/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9733 - loss: 0.0944 - val_accuracy: 0.9758 - val_loss: 0.0905
# Epoch 7/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9771 - loss: 0.0806 - val_accuracy: 0.9762 - val_loss: 0.0862
# Epoch 8/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9805 - loss: 0.0699 - val_accuracy: 0.9767 - val_loss: 0.0803
# Epoch 9/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9833 - loss: 0.0604 - val_accuracy: 0.9780 - val_loss: 0.0801
# Epoch 10/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9851 - loss: 0.0540 - val_accuracy: 0.9790 - val_loss: 0.0764
# Epoch 11/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9878 - loss: 0.0463 - val_accuracy: 0.9788 - val_loss: 0.0752
# Epoch 12/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9888 - loss: 0.0417 - val_accuracy: 0.9797 - val_loss: 0.0740
# Epoch 13/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9907 - loss: 0.0365 - val_accuracy: 0.9797 - val_loss: 0.0736
# Epoch 14/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9914 - loss: 0.0329 - val_accuracy: 0.9802 - val_loss: 0.0727
# Epoch 15/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9932 - loss: 0.0281 - val_accuracy: 0.9802 - val_loss: 0.0728
#
# ⏱️  Tiempo de entrenamiento: 10.77 segundos
#
# ▶▶▶ Configuración: Config_14
#     Neuronas capa oculta: 128
#     Épocas: 15
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.001
#     Validation split: 0.2
#     Optimizer: Adam (fijo)
# Epoch 1/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8678 - loss: 0.4940 - val_accuracy: 0.9283 - val_loss: 0.2617
# Epoch 2/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9360 - loss: 0.2291 - val_accuracy: 0.9451 - val_loss: 0.1948
# Epoch 3/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9508 - loss: 0.1720 - val_accuracy: 0.9562 - val_loss: 0.1554
# Epoch 4/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9604 - loss: 0.1378 - val_accuracy: 0.9607 - val_loss: 0.1340
# Epoch 5/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9677 - loss: 0.1138 - val_accuracy: 0.9652 - val_loss: 0.1211
# Epoch 6/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9723 - loss: 0.0976 - val_accuracy: 0.9653 - val_loss: 0.1159
# Epoch 7/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9765 - loss: 0.0838 - val_accuracy: 0.9686 - val_loss: 0.1067
# Epoch 8/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9794 - loss: 0.0731 - val_accuracy: 0.9678 - val_loss: 0.1073
# Epoch 9/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9821 - loss: 0.0644 - val_accuracy: 0.9707 - val_loss: 0.0966
# Epoch 10/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9852 - loss: 0.0560 - val_accuracy: 0.9726 - val_loss: 0.0930
# Epoch 11/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9865 - loss: 0.0501 - val_accuracy: 0.9738 - val_loss: 0.0904
# Epoch 12/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9884 - loss: 0.0437 - val_accuracy: 0.9747 - val_loss: 0.0866
# Epoch 13/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9896 - loss: 0.0386 - val_accuracy: 0.9738 - val_loss: 0.0864
# Epoch 14/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9909 - loss: 0.0346 - val_accuracy: 0.9743 - val_loss: 0.0871
# Epoch 15/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9922 - loss: 0.0307 - val_accuracy: 0.9748 - val_loss: 0.0861
#
# ⏱️  Tiempo de entrenamiento: 10.03 segundos
#
# ▶▶▶ Configuración: Config_15
#     Neuronas capa oculta: 128
#     Épocas: 15
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.01
#     Validation split: 0.1
#     Optimizer: Adam (fijo)
# Epoch 1/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9205 - loss: 0.2599 - val_accuracy: 0.9702 - val_loss: 0.1106
# Epoch 2/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9649 - loss: 0.1123 - val_accuracy: 0.9713 - val_loss: 0.0959
# Epoch 3/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9749 - loss: 0.0788 - val_accuracy: 0.9742 - val_loss: 0.0896
# Epoch 4/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9794 - loss: 0.0619 - val_accuracy: 0.9743 - val_loss: 0.0960
# Epoch 5/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9839 - loss: 0.0506 - val_accuracy: 0.9765 - val_loss: 0.1001
# Epoch 6/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9844 - loss: 0.0482 - val_accuracy: 0.9732 - val_loss: 0.1030
# Epoch 7/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9858 - loss: 0.0417 - val_accuracy: 0.9772 - val_loss: 0.0914
# Epoch 8/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9889 - loss: 0.0335 - val_accuracy: 0.9728 - val_loss: 0.1144
# Epoch 9/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9875 - loss: 0.0374 - val_accuracy: 0.9702 - val_loss: 0.1313
# Epoch 10/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9884 - loss: 0.0351 - val_accuracy: 0.9775 - val_loss: 0.1144
# Epoch 11/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9905 - loss: 0.0293 - val_accuracy: 0.9775 - val_loss: 0.1231
# Epoch 12/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9893 - loss: 0.0321 - val_accuracy: 0.9763 - val_loss: 0.1438
# Epoch 13/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9899 - loss: 0.0314 - val_accuracy: 0.9758 - val_loss: 0.1390
# Epoch 14/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9908 - loss: 0.0299 - val_accuracy: 0.9742 - val_loss: 0.1781
# Epoch 15/15
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9921 - loss: 0.0257 - val_accuracy: 0.9788 - val_loss: 0.1360
#
# ⏱️  Tiempo de entrenamiento: 10.60 segundos
#
# ▶▶▶ Configuración: Config_16
#     Neuronas capa oculta: 128
#     Épocas: 15
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.01
#     Validation split: 0.2
#     Optimizer: Adam (fijo)
# Epoch 1/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9194 - loss: 0.2691 - val_accuracy: 0.9576 - val_loss: 0.1413
# Epoch 2/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9640 - loss: 0.1168 - val_accuracy: 0.9686 - val_loss: 0.1042
# Epoch 3/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9748 - loss: 0.0794 - val_accuracy: 0.9671 - val_loss: 0.1146
# Epoch 4/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9797 - loss: 0.0629 - val_accuracy: 0.9688 - val_loss: 0.1058
# Epoch 5/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9839 - loss: 0.0518 - val_accuracy: 0.9706 - val_loss: 0.1102
# Epoch 6/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9868 - loss: 0.0402 - val_accuracy: 0.9707 - val_loss: 0.1123
# Epoch 7/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9875 - loss: 0.0376 - val_accuracy: 0.9724 - val_loss: 0.1049
# Epoch 8/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9882 - loss: 0.0345 - val_accuracy: 0.9704 - val_loss: 0.1209
# Epoch 9/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9903 - loss: 0.0291 - val_accuracy: 0.9733 - val_loss: 0.1188
# Epoch 10/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9895 - loss: 0.0316 - val_accuracy: 0.9720 - val_loss: 0.1355
# Epoch 11/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9883 - loss: 0.0369 - val_accuracy: 0.9710 - val_loss: 0.1328
# Epoch 12/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9913 - loss: 0.0281 - val_accuracy: 0.9744 - val_loss: 0.1259
# Epoch 13/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9919 - loss: 0.0271 - val_accuracy: 0.9737 - val_loss: 0.1414
# Epoch 14/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9909 - loss: 0.0300 - val_accuracy: 0.9681 - val_loss: 0.1827
# Epoch 15/15
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9933 - loss: 0.0219 - val_accuracy: 0.9743 - val_loss: 0.1488
#
# ⏱️  Tiempo de entrenamiento: 9.94 segundos
#
# ▶▶▶ Configuración: Config_17
#     Neuronas capa oculta: 128
#     Épocas: 20
#     Loss: sparse_categorical_crossentropy
#     Batch size: 128
#     Learning rate: 0.001
#     Validation split: 0.1
#     Optimizer: Adam (fijo)
# Epoch 1/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8958 - loss: 0.3776 - val_accuracy: 0.9550 - val_loss: 0.1704
# Epoch 2/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9501 - loss: 0.1759 - val_accuracy: 0.9643 - val_loss: 0.1285
# Epoch 3/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9634 - loss: 0.1277 - val_accuracy: 0.9707 - val_loss: 0.1051
# Epoch 4/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9713 - loss: 0.0988 - val_accuracy: 0.9735 - val_loss: 0.0917
# Epoch 5/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9772 - loss: 0.0799 - val_accuracy: 0.9755 - val_loss: 0.0823
# Epoch 6/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9806 - loss: 0.0666 - val_accuracy: 0.9768 - val_loss: 0.0796
# Epoch 7/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9844 - loss: 0.0551 - val_accuracy: 0.9758 - val_loss: 0.0783
# Epoch 8/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9871 - loss: 0.0469 - val_accuracy: 0.9777 - val_loss: 0.0760
# Epoch 9/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9884 - loss: 0.0407 - val_accuracy: 0.9787 - val_loss: 0.0775
# Epoch 10/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9903 - loss: 0.0349 - val_accuracy: 0.9763 - val_loss: 0.0748
# Epoch 11/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9921 - loss: 0.0294 - val_accuracy: 0.9788 - val_loss: 0.0748
# Epoch 12/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9940 - loss: 0.0243 - val_accuracy: 0.9788 - val_loss: 0.0720
# Epoch 13/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9948 - loss: 0.0217 - val_accuracy: 0.9798 - val_loss: 0.0702
# Epoch 14/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9961 - loss: 0.0182 - val_accuracy: 0.9790 - val_loss: 0.0779
# Epoch 15/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9967 - loss: 0.0155 - val_accuracy: 0.9803 - val_loss: 0.0710
# Epoch 16/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9974 - loss: 0.0130 - val_accuracy: 0.9792 - val_loss: 0.0745
# Epoch 17/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9977 - loss: 0.0115 - val_accuracy: 0.9802 - val_loss: 0.0724
# Epoch 18/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9987 - loss: 0.0091 - val_accuracy: 0.9808 - val_loss: 0.0743
# Epoch 19/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9987 - loss: 0.0083 - val_accuracy: 0.9780 - val_loss: 0.0769
# Epoch 20/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9991 - loss: 0.0065 - val_accuracy: 0.9785 - val_loss: 0.0859
#
# ⏱️  Tiempo de entrenamiento: 21.35 segundos
#
# ▶▶▶ Configuración: Config_18
#     Neuronas capa oculta: 128
#     Épocas: 20
#     Loss: sparse_categorical_crossentropy
#     Batch size: 128
#     Learning rate: 0.001
#     Validation split: 0.2
#     Optimizer: Adam (fijo)
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8906 - loss: 0.3988 - val_accuracy: 0.9423 - val_loss: 0.2123
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9468 - loss: 0.1853 - val_accuracy: 0.9567 - val_loss: 0.1596
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9609 - loss: 0.1358 - val_accuracy: 0.9613 - val_loss: 0.1341
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9693 - loss: 0.1060 - val_accuracy: 0.9632 - val_loss: 0.1191
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9762 - loss: 0.0853 - val_accuracy: 0.9687 - val_loss: 0.1078
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9799 - loss: 0.0710 - val_accuracy: 0.9718 - val_loss: 0.0973
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9833 - loss: 0.0591 - val_accuracy: 0.9712 - val_loss: 0.0967
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9863 - loss: 0.0497 - val_accuracy: 0.9723 - val_loss: 0.0903
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9882 - loss: 0.0420 - val_accuracy: 0.9743 - val_loss: 0.0869
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9909 - loss: 0.0353 - val_accuracy: 0.9743 - val_loss: 0.0855
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9918 - loss: 0.0310 - val_accuracy: 0.9744 - val_loss: 0.0887
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9937 - loss: 0.0265 - val_accuracy: 0.9743 - val_loss: 0.0868
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9948 - loss: 0.0224 - val_accuracy: 0.9758 - val_loss: 0.0854
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9959 - loss: 0.0189 - val_accuracy: 0.9749 - val_loss: 0.0883
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9967 - loss: 0.0165 - val_accuracy: 0.9772 - val_loss: 0.0869
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9971 - loss: 0.0137 - val_accuracy: 0.9762 - val_loss: 0.0859
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9981 - loss: 0.0116 - val_accuracy: 0.9760 - val_loss: 0.0931
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9983 - loss: 0.0099 - val_accuracy: 0.9770 - val_loss: 0.0954
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9987 - loss: 0.0085 - val_accuracy: 0.9773 - val_loss: 0.0885
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9989 - loss: 0.0073 - val_accuracy: 0.9753 - val_loss: 0.0985
#
# ⏱️  Tiempo de entrenamiento: 20.28 segundos
#
# ▶▶▶ Configuración: Config_19
#     Neuronas capa oculta: 128
#     Épocas: 20
#     Loss: sparse_categorical_crossentropy
#     Batch size: 128
#     Learning rate: 0.01
#     Validation split: 0.1
#     Optimizer: Adam (fijo)
# Epoch 1/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9317 - loss: 0.2247 - val_accuracy: 0.9705 - val_loss: 0.1139
# Epoch 2/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9651 - loss: 0.1132 - val_accuracy: 0.9675 - val_loss: 0.1109
# Epoch 3/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9738 - loss: 0.0853 - val_accuracy: 0.9655 - val_loss: 0.1246
# Epoch 4/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9757 - loss: 0.0783 - val_accuracy: 0.9603 - val_loss: 0.1525
# Epoch 5/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9791 - loss: 0.0679 - val_accuracy: 0.9710 - val_loss: 0.1130
# Epoch 6/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9812 - loss: 0.0622 - val_accuracy: 0.9680 - val_loss: 0.1384
# Epoch 7/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9812 - loss: 0.0609 - val_accuracy: 0.9772 - val_loss: 0.1077
# Epoch 8/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9839 - loss: 0.0562 - val_accuracy: 0.9725 - val_loss: 0.1377
# Epoch 9/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9864 - loss: 0.0480 - val_accuracy: 0.9740 - val_loss: 0.1408
# Epoch 10/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9857 - loss: 0.0523 - val_accuracy: 0.9680 - val_loss: 0.1614
# Epoch 11/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9851 - loss: 0.0580 - val_accuracy: 0.9730 - val_loss: 0.1684
# Epoch 12/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9868 - loss: 0.0511 - val_accuracy: 0.9735 - val_loss: 0.1592
# Epoch 13/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9894 - loss: 0.0392 - val_accuracy: 0.9752 - val_loss: 0.1745
# Epoch 14/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9911 - loss: 0.0351 - val_accuracy: 0.9722 - val_loss: 0.1995
# Epoch 15/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9893 - loss: 0.0413 - val_accuracy: 0.9738 - val_loss: 0.1887
# Epoch 16/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9884 - loss: 0.0496 - val_accuracy: 0.9702 - val_loss: 0.2394
# Epoch 17/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9911 - loss: 0.0346 - val_accuracy: 0.9747 - val_loss: 0.1825
# Epoch 18/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9924 - loss: 0.0307 - val_accuracy: 0.9730 - val_loss: 0.2194
# Epoch 19/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9919 - loss: 0.0335 - val_accuracy: 0.9763 - val_loss: 0.1987
# Epoch 20/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9905 - loss: 0.0409 - val_accuracy: 0.9730 - val_loss: 0.2288
#
# ⏱️  Tiempo de entrenamiento: 21.30 segundos
#
# ▶▶▶ Configuración: Config_20
#     Neuronas capa oculta: 128
#     Épocas: 20
#     Loss: sparse_categorical_crossentropy
#     Batch size: 128
#     Learning rate: 0.01
#     Validation split: 0.2
#     Optimizer: Adam (fijo)
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9295 - loss: 0.2353 - val_accuracy: 0.9587 - val_loss: 0.1271
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9655 - loss: 0.1139 - val_accuracy: 0.9695 - val_loss: 0.1077
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9744 - loss: 0.0859 - val_accuracy: 0.9637 - val_loss: 0.1326
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9763 - loss: 0.0748 - val_accuracy: 0.9678 - val_loss: 0.1193
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9803 - loss: 0.0622 - val_accuracy: 0.9661 - val_loss: 0.1338
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9816 - loss: 0.0619 - val_accuracy: 0.9663 - val_loss: 0.1559
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9806 - loss: 0.0657 - val_accuracy: 0.9698 - val_loss: 0.1404
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9845 - loss: 0.0515 - val_accuracy: 0.9643 - val_loss: 0.1718
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9863 - loss: 0.0426 - val_accuracy: 0.9655 - val_loss: 0.1874
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9868 - loss: 0.0466 - val_accuracy: 0.9703 - val_loss: 0.1637
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9878 - loss: 0.0407 - val_accuracy: 0.9645 - val_loss: 0.1969
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9869 - loss: 0.0454 - val_accuracy: 0.9708 - val_loss: 0.1854
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9887 - loss: 0.0421 - val_accuracy: 0.9697 - val_loss: 0.1951
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9886 - loss: 0.0422 - val_accuracy: 0.9684 - val_loss: 0.2210
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9907 - loss: 0.0339 - val_accuracy: 0.9692 - val_loss: 0.2300
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9907 - loss: 0.0358 - val_accuracy: 0.9699 - val_loss: 0.2301
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9910 - loss: 0.0372 - val_accuracy: 0.9708 - val_loss: 0.2595
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9906 - loss: 0.0363 - val_accuracy: 0.9685 - val_loss: 0.2633
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9915 - loss: 0.0357 - val_accuracy: 0.9706 - val_loss: 0.2665
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9910 - loss: 0.0362 - val_accuracy: 0.9707 - val_loss: 0.2800
#
# ⏱️  Tiempo de entrenamiento: 20.14 segundos
#
# ▶▶▶ Configuración: Config_21
#     Neuronas capa oculta: 128
#     Épocas: 20
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.001
#     Validation split: 0.1
#     Optimizer: Adam (fijo)
# Epoch 1/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8729 - loss: 0.4783 - val_accuracy: 0.9480 - val_loss: 0.2007
# Epoch 2/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9404 - loss: 0.2108 - val_accuracy: 0.9615 - val_loss: 0.1448
# Epoch 3/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9549 - loss: 0.1559 - val_accuracy: 0.9657 - val_loss: 0.1178
# Epoch 4/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9650 - loss: 0.1226 - val_accuracy: 0.9710 - val_loss: 0.1031
# Epoch 5/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9712 - loss: 0.1013 - val_accuracy: 0.9718 - val_loss: 0.0964
# Epoch 6/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9755 - loss: 0.0859 - val_accuracy: 0.9772 - val_loss: 0.0852
# Epoch 7/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9783 - loss: 0.0733 - val_accuracy: 0.9745 - val_loss: 0.0855
# Epoch 8/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9816 - loss: 0.0639 - val_accuracy: 0.9777 - val_loss: 0.0796
# Epoch 9/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9839 - loss: 0.0555 - val_accuracy: 0.9777 - val_loss: 0.0744
# Epoch 10/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9869 - loss: 0.0479 - val_accuracy: 0.9782 - val_loss: 0.0762
# Epoch 11/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9890 - loss: 0.0424 - val_accuracy: 0.9800 - val_loss: 0.0733
# Epoch 12/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9898 - loss: 0.0377 - val_accuracy: 0.9798 - val_loss: 0.0756
# Epoch 13/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9912 - loss: 0.0333 - val_accuracy: 0.9808 - val_loss: 0.0742
# Epoch 14/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9927 - loss: 0.0296 - val_accuracy: 0.9807 - val_loss: 0.0706
# Epoch 15/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - loss: 0.0261 - val_accuracy: 0.9793 - val_loss: 0.0750
# Epoch 16/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9947 - loss: 0.0231 - val_accuracy: 0.9810 - val_loss: 0.0692
# Epoch 17/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9955 - loss: 0.0207 - val_accuracy: 0.9783 - val_loss: 0.0752
# Epoch 18/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9963 - loss: 0.0183 - val_accuracy: 0.9795 - val_loss: 0.0734
# Epoch 19/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9971 - loss: 0.0159 - val_accuracy: 0.9780 - val_loss: 0.0759
# Epoch 20/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9975 - loss: 0.0145 - val_accuracy: 0.9815 - val_loss: 0.0742
#
# ⏱️  Tiempo de entrenamiento: 13.40 segundos
#
# ▶▶▶ Configuración: Config_22
#     Neuronas capa oculta: 128
#     Épocas: 20
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.001
#     Validation split: 0.2
#     Optimizer: Adam (fijo)
# Epoch 1/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8644 - loss: 0.5027 - val_accuracy: 0.9300 - val_loss: 0.2519
# Epoch 2/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9361 - loss: 0.2287 - val_accuracy: 0.9448 - val_loss: 0.1939
# Epoch 3/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9503 - loss: 0.1762 - val_accuracy: 0.9550 - val_loss: 0.1620
# Epoch 4/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9595 - loss: 0.1434 - val_accuracy: 0.9582 - val_loss: 0.1465
# Epoch 5/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9658 - loss: 0.1201 - val_accuracy: 0.9632 - val_loss: 0.1290
# Epoch 6/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9716 - loss: 0.1015 - val_accuracy: 0.9673 - val_loss: 0.1159
# Epoch 7/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9750 - loss: 0.0877 - val_accuracy: 0.9688 - val_loss: 0.1122
# Epoch 8/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9791 - loss: 0.0765 - val_accuracy: 0.9703 - val_loss: 0.1052
# Epoch 9/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9811 - loss: 0.0676 - val_accuracy: 0.9719 - val_loss: 0.0981
# Epoch 10/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9840 - loss: 0.0596 - val_accuracy: 0.9712 - val_loss: 0.0979
# Epoch 11/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9856 - loss: 0.0532 - val_accuracy: 0.9732 - val_loss: 0.0949
# Epoch 12/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9871 - loss: 0.0481 - val_accuracy: 0.9726 - val_loss: 0.0907
# Epoch 13/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9888 - loss: 0.0426 - val_accuracy: 0.9742 - val_loss: 0.0882
# Epoch 14/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9904 - loss: 0.0380 - val_accuracy: 0.9737 - val_loss: 0.0884
# Epoch 15/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9920 - loss: 0.0331 - val_accuracy: 0.9745 - val_loss: 0.0860
# Epoch 16/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9924 - loss: 0.0306 - val_accuracy: 0.9747 - val_loss: 0.0865
# Epoch 17/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9945 - loss: 0.0261 - val_accuracy: 0.9743 - val_loss: 0.0860
# Epoch 18/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9954 - loss: 0.0236 - val_accuracy: 0.9743 - val_loss: 0.0891
# Epoch 19/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9955 - loss: 0.0214 - val_accuracy: 0.9739 - val_loss: 0.0869
# Epoch 20/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9964 - loss: 0.0192 - val_accuracy: 0.9750 - val_loss: 0.0856
#
# ⏱️  Tiempo de entrenamiento: 13.14 segundos
#
# ▶▶▶ Configuración: Config_23
#     Neuronas capa oculta: 128
#     Épocas: 20
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.01
#     Validation split: 0.1
#     Optimizer: Adam (fijo)
# Epoch 1/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9224 - loss: 0.2553 - val_accuracy: 0.9703 - val_loss: 0.1023
# Epoch 2/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9665 - loss: 0.1079 - val_accuracy: 0.9695 - val_loss: 0.1120
# Epoch 3/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9743 - loss: 0.0794 - val_accuracy: 0.9740 - val_loss: 0.0913
# Epoch 4/20
# ...
# Epoch 7/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9818 - loss: 0.0672 - val_accuracy: 0.9723 - val_loss: 0.1312
# Epoch 8/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9844 - loss: 0.0567 - val_accuracy: 0.9700 - val_loss: 0.1569
# Epoch 9/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9850 - loss: 0.0571 - val_accuracy: 0.9698 - val_loss: 0.1720
# Epoch 10/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9862 - loss: 0.0562 - val_accuracy: 0.9702 - val_loss: 0.1748
# Epoch 11/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9855 - loss: 0.0589 - val_accuracy: 0.9750 - val_loss: 0.1532
# Epoch 12/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9883 - loss: 0.0482 - val_accuracy: 0.9755 - val_loss: 0.1489
# Epoch 13/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9892 - loss: 0.0439 - val_accuracy: 0.9745 - val_loss: 0.1707
# Epoch 14/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9895 - loss: 0.0459 - val_accuracy: 0.9735 - val_loss: 0.1782
# Epoch 15/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9919 - loss: 0.0326 - val_accuracy: 0.9750 - val_loss: 0.1902
# Epoch 16/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9904 - loss: 0.0434 - val_accuracy: 0.9735 - val_loss: 0.2247
# Epoch 17/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9910 - loss: 0.0423 - val_accuracy: 0.9713 - val_loss: 0.2684
# Epoch 18/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9922 - loss: 0.0354 - val_accuracy: 0.9753 - val_loss: 0.2181
# Epoch 19/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9917 - loss: 0.0447 - val_accuracy: 0.9767 - val_loss: 0.2343
# Epoch 20/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9924 - loss: 0.0388 - val_accuracy: 0.9770 - val_loss: 0.2333
#
# ⏱️  Tiempo de entrenamiento: 37.91 segundos
#
# ▶▶▶ Configuración: Config_68
#     Neuronas capa oculta: 512
#     Épocas: 20
#     Loss: sparse_categorical_crossentropy
#     Batch size: 128
#     Learning rate: 0.01
#     Validation split: 0.2
#     Optimizer: Adam (fijo)
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9297 - loss: 0.2346 - val_accuracy: 0.9548 - val_loss: 0.1452
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9667 - loss: 0.1110 - val_accuracy: 0.9619 - val_loss: 0.1408
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9739 - loss: 0.0919 - val_accuracy: 0.9667 - val_loss: 0.1318
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9778 - loss: 0.0746 - val_accuracy: 0.9688 - val_loss: 0.1413
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9793 - loss: 0.0707 - val_accuracy: 0.9648 - val_loss: 0.1767
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9814 - loss: 0.0651 - val_accuracy: 0.9711 - val_loss: 0.1487
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9842 - loss: 0.0530 - val_accuracy: 0.9697 - val_loss: 0.1560
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9853 - loss: 0.0528 - val_accuracy: 0.9690 - val_loss: 0.1878
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9832 - loss: 0.0672 - val_accuracy: 0.9682 - val_loss: 0.1908
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9879 - loss: 0.0452 - val_accuracy: 0.9715 - val_loss: 0.1851
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9895 - loss: 0.0376 - val_accuracy: 0.9698 - val_loss: 0.1974
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9888 - loss: 0.0489 - val_accuracy: 0.9699 - val_loss: 0.2280
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9885 - loss: 0.0498 - val_accuracy: 0.9686 - val_loss: 0.2667
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9888 - loss: 0.0509 - val_accuracy: 0.9710 - val_loss: 0.2448
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9904 - loss: 0.0405 - val_accuracy: 0.9729 - val_loss: 0.2383
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9911 - loss: 0.0403 - val_accuracy: 0.9712 - val_loss: 0.2759
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9912 - loss: 0.0463 - val_accuracy: 0.9699 - val_loss: 0.2846
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9924 - loss: 0.0382 - val_accuracy: 0.9722 - val_loss: 0.2857
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9923 - loss: 0.0357 - val_accuracy: 0.9740 - val_loss: 0.2928
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9910 - loss: 0.0474 - val_accuracy: 0.9688 - val_loss: 0.3287
#
# ⏱️  Tiempo de entrenamiento: 36.30 segundos
#
# ▶▶▶ Configuración: Config_69
#     Neuronas capa oculta: 512
#     Épocas: 20
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.001
#     Validation split: 0.1
#     Optimizer: Adam (fijo)
# Epoch 1/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9039 - loss: 0.3516 - val_accuracy: 0.9547 - val_loss: 0.1601
# Epoch 2/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9572 - loss: 0.1518 - val_accuracy: 0.9707 - val_loss: 0.1059
# Epoch 3/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9712 - loss: 0.0999 - val_accuracy: 0.9735 - val_loss: 0.0894
# Epoch 4/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9789 - loss: 0.0741 - val_accuracy: 0.9773 - val_loss: 0.0786
# Epoch 5/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9844 - loss: 0.0562 - val_accuracy: 0.9787 - val_loss: 0.0785
# Epoch 6/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9878 - loss: 0.0444 - val_accuracy: 0.9805 - val_loss: 0.0661
# Epoch 7/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9904 - loss: 0.0349 - val_accuracy: 0.9820 - val_loss: 0.0685
# Epoch 8/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9926 - loss: 0.0284 - val_accuracy: 0.9815 - val_loss: 0.0656
# Epoch 9/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9949 - loss: 0.0215 - val_accuracy: 0.9825 - val_loss: 0.0651
# Epoch 10/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9963 - loss: 0.0173 - val_accuracy: 0.9792 - val_loss: 0.0690
# Epoch 11/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9970 - loss: 0.0145 - val_accuracy: 0.9817 - val_loss: 0.0668
# Epoch 12/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9982 - loss: 0.0110 - val_accuracy: 0.9827 - val_loss: 0.0669
# Epoch 13/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9989 - loss: 0.0085 - val_accuracy: 0.9825 - val_loss: 0.0660
# Epoch 14/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9991 - loss: 0.0071 - val_accuracy: 0.9818 - val_loss: 0.0644
# Epoch 15/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9994 - loss: 0.0057 - val_accuracy: 0.9827 - val_loss: 0.0658
# Epoch 16/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9996 - loss: 0.0047 - val_accuracy: 0.9825 - val_loss: 0.0671
# Epoch 17/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9998 - loss: 0.0036 - val_accuracy: 0.9833 - val_loss: 0.0658
# Epoch 18/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9998 - loss: 0.0031 - val_accuracy: 0.9840 - val_loss: 0.0664
# Epoch 19/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9995 - loss: 0.0040 - val_accuracy: 0.9800 - val_loss: 0.0758
# Epoch 20/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9996 - loss: 0.0035 - val_accuracy: 0.9830 - val_loss: 0.0676
#
# ⏱️  Tiempo de entrenamiento: 28.42 segundos
#
# ▶▶▶ Configuración: Config_70
#     Neuronas capa oculta: 512
#     Épocas: 20
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.001
#     Validation split: 0.2
#     Optimizer: Adam (fijo)
# Epoch 1/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8977 - loss: 0.3638 - val_accuracy: 0.9474 - val_loss: 0.1875
# Epoch 2/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9550 - loss: 0.1569 - val_accuracy: 0.9638 - val_loss: 0.1311
# Epoch 3/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9696 - loss: 0.1073 - val_accuracy: 0.9670 - val_loss: 0.1098
# Epoch 4/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9777 - loss: 0.0795 - val_accuracy: 0.9718 - val_loss: 0.0963
# Epoch 5/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9835 - loss: 0.0610 - val_accuracy: 0.9738 - val_loss: 0.0852
# Epoch 6/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9869 - loss: 0.0472 - val_accuracy: 0.9744 - val_loss: 0.0832
# Epoch 7/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9902 - loss: 0.0376 - val_accuracy: 0.9754 - val_loss: 0.0804
# Epoch 8/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9930 - loss: 0.0300 - val_accuracy: 0.9748 - val_loss: 0.0810
# Epoch 9/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9943 - loss: 0.0239 - val_accuracy: 0.9779 - val_loss: 0.0730
# Epoch 10/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9957 - loss: 0.0194 - val_accuracy: 0.9778 - val_loss: 0.0748
# Epoch 11/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9973 - loss: 0.0152 - val_accuracy: 0.9784 - val_loss: 0.0737
# Epoch 12/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9984 - loss: 0.0115 - val_accuracy: 0.9784 - val_loss: 0.0738
# Epoch 13/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9987 - loss: 0.0098 - val_accuracy: 0.9786 - val_loss: 0.0720
# Epoch 14/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9993 - loss: 0.0072 - val_accuracy: 0.9796 - val_loss: 0.0750
# Epoch 15/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9994 - loss: 0.0059 - val_accuracy: 0.9788 - val_loss: 0.0749
# Epoch 16/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9996 - loss: 0.0048 - val_accuracy: 0.9796 - val_loss: 0.0764
# Epoch 17/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9998 - loss: 0.0039 - val_accuracy: 0.9797 - val_loss: 0.0729
# Epoch 18/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9999 - loss: 0.0033 - val_accuracy: 0.9803 - val_loss: 0.0749
# Epoch 19/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9999 - loss: 0.0029 - val_accuracy: 0.9791 - val_loss: 0.0767
# Epoch 20/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9803 - val_loss: 0.0749
#
# ⏱️  Tiempo de entrenamiento: 25.61 segundos
#
# ▶▶▶ Configuración: Config_71
#     Neuronas capa oculta: 512
#     Épocas: 20
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.01
#     Validation split: 0.1
#     Optimizer: Adam (fijo)
# Epoch 1/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9304 - loss: 0.2264 - val_accuracy: 0.9675 - val_loss: 0.1186
# Epoch 2/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9703 - loss: 0.0957 - val_accuracy: 0.9672 - val_loss: 0.1110
# Epoch 3/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9764 - loss: 0.0738 - val_accuracy: 0.9738 - val_loss: 0.0907
# Epoch 4/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9818 - loss: 0.0581 - val_accuracy: 0.9742 - val_loss: 0.1005
# Epoch 5/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9857 - loss: 0.0465 - val_accuracy: 0.9773 - val_loss: 0.0985
# Epoch 6/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9866 - loss: 0.0428 - val_accuracy: 0.9773 - val_loss: 0.1053
# Epoch 7/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9876 - loss: 0.0398 - val_accuracy: 0.9777 - val_loss: 0.0991
# Epoch 8/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9849 - loss: 0.0511 - val_accuracy: 0.9728 - val_loss: 0.1215
# Epoch 9/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9876 - loss: 0.0451 - val_accuracy: 0.9802 - val_loss: 0.1147
# Epoch 10/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9896 - loss: 0.0364 - val_accuracy: 0.9765 - val_loss: 0.1450
# Epoch 11/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9901 - loss: 0.0358 - val_accuracy: 0.9772 - val_loss: 0.1642
# Epoch 12/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9907 - loss: 0.0348 - val_accuracy: 0.9792 - val_loss: 0.1285
# Epoch 13/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9918 - loss: 0.0297 - val_accuracy: 0.9770 - val_loss: 0.1532
# Epoch 14/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9909 - loss: 0.0360 - val_accuracy: 0.9740 - val_loss: 0.1785
# Epoch 15/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9915 - loss: 0.0324 - val_accuracy: 0.9782 - val_loss: 0.1504
# Epoch 16/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9913 - loss: 0.0337 - val_accuracy: 0.9775 - val_loss: 0.1871
# Epoch 17/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9928 - loss: 0.0296 - val_accuracy: 0.9765 - val_loss: 0.1752
# Epoch 18/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9927 - loss: 0.0275 - val_accuracy: 0.9778 - val_loss: 0.1677
# Epoch 19/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9937 - loss: 0.0288 - val_accuracy: 0.9797 - val_loss: 0.2280
# Epoch 20/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9929 - loss: 0.0316 - val_accuracy: 0.9762 - val_loss: 0.2215
#
# ⏱️  Tiempo de entrenamiento: 27.17 segundos
#
# ▶▶▶ Configuración: Config_72
#     Neuronas capa oculta: 512
#     Épocas: 20
#     Loss: sparse_categorical_crossentropy
#     Batch size: 256
#     Learning rate: 0.01
#     Validation split: 0.2
#     Optimizer: Adam (fijo)
# Epoch 1/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9230 - loss: 0.2583 - val_accuracy: 0.9566 - val_loss: 0.1485
# Epoch 2/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9695 - loss: 0.0975 - val_accuracy: 0.9700 - val_loss: 0.1085
# Epoch 3/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9783 - loss: 0.0687 - val_accuracy: 0.9663 - val_loss: 0.1206
# Epoch 4/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9817 - loss: 0.0560 - val_accuracy: 0.9672 - val_loss: 0.1213
# Epoch 5/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9835 - loss: 0.0521 - val_accuracy: 0.9728 - val_loss: 0.1070
# Epoch 6/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9879 - loss: 0.0368 - val_accuracy: 0.9743 - val_loss: 0.1098
# Epoch 7/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9875 - loss: 0.0379 - val_accuracy: 0.9729 - val_loss: 0.1302
# Epoch 8/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9878 - loss: 0.0394 - val_accuracy: 0.9688 - val_loss: 0.1556
# Epoch 9/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9877 - loss: 0.0377 - val_accuracy: 0.9733 - val_loss: 0.1638
# Epoch 10/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9914 - loss: 0.0275 - val_accuracy: 0.9675 - val_loss: 0.1884
# Epoch 11/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9917 - loss: 0.0261 - val_accuracy: 0.9763 - val_loss: 0.1454
# Epoch 12/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9913 - loss: 0.0301 - val_accuracy: 0.9688 - val_loss: 0.2047
# Epoch 13/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9929 - loss: 0.0249 - val_accuracy: 0.9745 - val_loss: 0.1697
# Epoch 14/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9889 - loss: 0.0457 - val_accuracy: 0.9738 - val_loss: 0.1857
# Epoch 15/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9912 - loss: 0.0336 - val_accuracy: 0.9736 - val_loss: 0.2040
# Epoch 16/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9932 - loss: 0.0266 - val_accuracy: 0.9753 - val_loss: 0.1893
# Epoch 17/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9934 - loss: 0.0267 - val_accuracy: 0.9737 - val_loss: 0.2159
# Epoch 18/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9929 - loss: 0.0280 - val_accuracy: 0.9738 - val_loss: 0.2248
# Epoch 19/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9933 - loss: 0.0283 - val_accuracy: 0.9743 - val_loss: 0.2294
# Epoch 20/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9947 - loss: 0.0222 - val_accuracy: 0.9742 - val_loss: 0.2360
#
# ⏱️  Tiempo de entrenamiento: 27.31 segundos

# %% [markdown]
# # 7. Tabla comparativa de resultados

# %%
comparison_data = []
for name, results in all_results.items():
    comparison_data.append({
        'Configuración': name,
        'Neuronas': results['config']['hidden_neurons'],
        'Épocas': results['config']['epochs'],
        'Loss': results['config']['loss'],
        'Batch Size': results['config']['batch_size'],
        'LR': results['config']['lr'],
        'Val Split': results['config']['validation_split'],
        'Val Loss': f"{results['val_loss']:.4f}",
        'Val Accuracy': f"{results['val_accuracy']:.4f}",
        'Tiempo (s)': f"{results['training_time']:.2f}"
    })

df_comparison = pd.DataFrame(comparison_data)
print(df_comparison.to_string(index=False))

# Guardar a CSV
os.makedirs('results', exist_ok=True)
df_comparison.to_csv('results/comparison_table.csv', index=False)
print("\n💾 Tabla guardada en: results/comparison_table.csv")

# Identificar mejor configuración
best_config = max(all_results.items(), key=lambda x: x[1]['val_accuracy'])
print(f"\n🏆 MEJOR CONFIGURACIÓN: {best_config[0]}")
print(f"   Val Accuracy: {best_config[1]['val_accuracy']:.4f}")
print(f"   Val Loss: {best_config[1]['val_loss']:.4f}")
print(f"   Training Time: {best_config[1]['training_time']:.2f}s")
# Out:
# Configuración  Neuronas  Épocas                            Loss  Batch Size    LR  Val Split Val Loss Val Accuracy Tiempo (s)
#      Config_1       128      10 sparse_categorical_crossentropy         128 0.001        0.1   0.0773       0.9773      11.16
#      Config_2       128      10 sparse_categorical_crossentropy         128 0.001        0.2   0.0840       0.9742      10.56
#      Config_3       128      10 sparse_categorical_crossentropy         128 0.010        0.1   0.1352       0.9772      11.24
#      Config_4       128      10 sparse_categorical_crossentropy         128 0.010        0.2   0.1884       0.9689      10.91
#      Config_5       128      10 sparse_categorical_crossentropy         256 0.001        0.1   0.0807       0.9750       7.36
#      Config_6       128      10 sparse_categorical_crossentropy         256 0.001        0.2   0.0925       0.9718       6.97
#      Config_7       128      10 sparse_categorical_crossentropy         256 0.010        0.1   0.1217       0.9755       7.12
#      Config_8       128      10 sparse_categorical_crossentropy         256 0.010        0.2   0.1367       0.9707       7.16
#      Config_9       128      15 sparse_categorical_crossentropy         128 0.001        0.1   0.0828       0.9793      16.70
#     Config_10       128      15 sparse_categorical_crossentropy         128 0.001        0.2   0.0900       0.9736      16.16
#     Config_11       128      15 sparse_categorical_crossentropy         128 0.010        0.1   0.2127       0.9692      16.07
#     Config_12       128      15 sparse_categorical_crossentropy         128 0.010        0.2   0.2279       0.9675      15.47
#     Config_13       128      15 sparse_categorical_crossentropy         256 0.001        0.1   0.0728       0.9802      10.77
#     Config_14       128      15 sparse_categorical_crossentropy         256 0.001        0.2   0.0861       0.9748      10.03
#     Config_15       128      15 sparse_categorical_crossentropy         256 0.010        0.1   0.1360       0.9788      10.60
#     Config_16       128      15 sparse_categorical_crossentropy         256 0.010        0.2   0.1488       0.9743       9.94
#     Config_17       128      20 sparse_categorical_crossentropy         128 0.001        0.1   0.0859       0.9785      21.35
#     Config_18       128      20 sparse_categorical_crossentropy         128 0.001        0.2   0.0985       0.9753      20.28
#     Config_19       128      20 sparse_categorical_crossentropy         128 0.010        0.1   0.2288       0.9730      21.30
#     Config_20       128      20 sparse_categorical_crossentropy         128 0.010        0.2   0.2800       0.9707      20.14
#     Config_21       128      20 sparse_categorical_crossentropy         256 0.001        0.1   0.0742       0.9815      13.40
#     Config_22       128      20 sparse_categorical_crossentropy         256 0.001        0.2   0.0856       0.9750      13.14
#     Config_23       128      20 sparse_categorical_crossentropy         256 0.010        0.1   0.1647       0.9790      13.53
#     Config_24       128      20 sparse_categorical_crossentropy         256 0.010        0.2   0.2496       0.9679      13.14
#     Config_25       256      10 sparse_categorical_crossentropy         128 0.001        0.1   0.0714       0.9817      14.19
#     Config_26       256      10 sparse_categorical_crossentropy         128 0.001        0.2   0.0788       0.9777      13.42
#     Config_27       256      10 sparse_categorical_crossentropy         128 0.010        0.1   0.1563       0.9765      14.15
#     Config_28       256      10 sparse_categorical_crossentropy         128 0.010        0.2   0.1841       0.9686      12.80
#     Config_29       256      10 sparse_categorical_crossentropy         256 0.001        0.1   0.0688       0.9817       9.25
#     Config_30       256      10 sparse_categorical_crossentropy         256 0.001        0.2   0.0830       0.9753       8.76
#     Config_31       256      10 sparse_categorical_crossentropy         256 0.010        0.1   0.1342       0.9755       9.36
#     Config_32       256      10 sparse_categorical_crossentropy         256 0.010        0.2   0.1251       0.9740       9.11
#     Config_33       256      15 sparse_categorical_crossentropy         128 0.001        0.1   0.0770       0.9807      20.77
#     Config_34       256      15 sparse_categorical_crossentropy         128 0.001        0.2   0.0873       0.9772      19.13
#     Config_35       256      15 sparse_categorical_crossentropy         128 0.010        0.1   0.2351       0.9728      20.25
#     Config_36       256      15 sparse_categorical_crossentropy         128 0.010        0.2   0.2114       0.9723      19.03
#     Config_37       256      15 sparse_categorical_crossentropy         256 0.001        0.1   0.0703       0.9813      13.86
#     Config_38       256      15 sparse_categorical_crossentropy         256 0.001        0.2   0.0790       0.9771      13.05
#     Config_39       256      15 sparse_categorical_crossentropy         256 0.010        0.1   0.2081       0.9772      13.73
#     Config_40       256      15 sparse_categorical_crossentropy         256 0.010        0.2   0.1638       0.9747      13.52
#     Config_41       256      20 sparse_categorical_crossentropy         128 0.001        0.1   0.0798       0.9840      28.30
#     Config_42       256      20 sparse_categorical_crossentropy         128 0.001        0.2   0.0842       0.9791      25.53
#     Config_43       256      20 sparse_categorical_crossentropy         128 0.010        0.1   0.2527       0.9753      27.59
#     Config_44       256      20 sparse_categorical_crossentropy         128 0.010        0.2   0.2841       0.9727      25.76
#     Config_45       256      20 sparse_categorical_crossentropy         256 0.001        0.1   0.0723       0.9813      17.92
#     Config_46       256      20 sparse_categorical_crossentropy         256 0.001        0.2   0.0843       0.9762      18.06
#     Config_47       256      20 sparse_categorical_crossentropy         256 0.010        0.1   0.2184       0.9777      18.23
#     Config_48       256      20 sparse_categorical_crossentropy         256 0.010        0.2   0.2878       0.9691      17.72
#     Config_49       512      10 sparse_categorical_crossentropy         128 0.001        0.1   0.0695       0.9823      19.48
#     Config_50       512      10 sparse_categorical_crossentropy         128 0.001        0.2   0.0865       0.9768      18.23
#     Config_51       512      10 sparse_categorical_crossentropy         128 0.010        0.1   0.1607       0.9747      19.35
#     Config_52       512      10 sparse_categorical_crossentropy         128 0.010        0.2   0.1618       0.9750      18.53
#     Config_53       512      10 sparse_categorical_crossentropy         256 0.001        0.1   0.0680       0.9798      15.21
#     Config_54       512      10 sparse_categorical_crossentropy         256 0.001        0.2   0.0742       0.9779      13.29
#     Config_55       512      10 sparse_categorical_crossentropy         256 0.010        0.1   0.1512       0.9742      13.99
#     Config_56       512      10 sparse_categorical_crossentropy         256 0.010        0.2   0.1609       0.9723      13.36
#     Config_57       512      15 sparse_categorical_crossentropy         128 0.001        0.1   0.0865       0.9820      29.55
#     Config_58       512      15 sparse_categorical_crossentropy         128 0.001        0.2   0.0920       0.9777      28.43
#     Config_59       512      15 sparse_categorical_crossentropy         128 0.010        0.1   0.1762       0.9767      29.25
#     Config_60       512      15 sparse_categorical_crossentropy         128 0.010        0.2   0.2078       0.9748      27.13
#     Config_61       512      15 sparse_categorical_crossentropy         256 0.001        0.1   0.0632       0.9842      20.57
#     Config_62       512      15 sparse_categorical_crossentropy         256 0.001        0.2   0.0735       0.9793      20.31
#     Config_63       512      15 sparse_categorical_crossentropy         256 0.010        0.1   0.1979       0.9740      20.41
#     Config_64       512      15 sparse_categorical_crossentropy         256 0.010        0.2   0.1881       0.9729      19.57
#     Config_65       512      20 sparse_categorical_crossentropy         128 0.001        0.1   0.0797       0.9838      37.66
#     Config_66       512      20 sparse_categorical_crossentropy         128 0.001        0.2   0.0840       0.9818      35.81
#     Config_67       512      20 sparse_categorical_crossentropy         128 0.010        0.1   0.2333       0.9770      37.91
#     Config_68       512      20 sparse_categorical_crossentropy         128 0.010        0.2   0.3287       0.9688      36.30
#     Config_69       512      20 sparse_categorical_crossentropy         256 0.001        0.1   0.0676       0.9830      28.42
#     Config_70       512      20 sparse_categorical_crossentropy         256 0.001        0.2   0.0749       0.9803      25.61
#     Config_71       512      20 sparse_categorical_crossentropy         256 0.010        0.1   0.2215       0.9762      27.17
#     Config_72       512      20 sparse_categorical_crossentropy         256 0.010        0.2   0.2360       0.9742      27.31
#
# 💾 Tabla guardada en: results/comparison_table.csv
#
# 🏆 MEJOR CONFIGURACIÓN: Config_61
#    Val Accuracy: 0.9842
#    Val Loss: 0.0632
#    Training Time: 20.57s

# %% [markdown]
# # 8. Evaluación de la mejor configuración

# %%
results_test = evaluate_model(all_results[best_config[0]]['model'], x_test, y_test)

print(f"\n✅ RESULTADOS FINALES DEL MEJOR MODELO:")
print(f"   Config: {best_config[0]}")
print(f"   Test Accuracy: {results_test['accuracy']:.4f}")
print(f"   Test Loss: {results_test['loss']:.4f}")
print(f"   Test Errors: {results_test['errors']}/{len(y_test)}")
# Out:
# Loss: 0.0607, Accuracy: 0.9817
# Errors:  183/10000 (1.83%)
#
# ✅ RESULTADOS FINALES DEL MEJOR MODELO:
#    Config: Config_61
#    Test Accuracy: 0.9817
#    Test Loss: 0.0607
#    Test Errors: 183/10000

# %% [markdown]
# # 9. Visualizaciones comparativas

# %%
# Gráfica comparativa: Loss durante entrenamiento
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
for name, history in all_histories.items():
    plt.plot(history.history['val_loss'], label=name, linewidth=2, alpha=0.8)
plt.xlabel('Época', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.title('Comparación de Loss en Entrenamiento', fontsize=14, fontweight='bold')
plt.legend(fontsize=9)
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
for name, history in all_histories.items():
    plt.plot(history.history['val_accuracy'], label=name, linewidth=2, alpha=0.8)
plt.xlabel('Época', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.title('Comparación de Accuracy en Entrenamiento', fontsize=14, fontweight='bold')
plt.legend(fontsize=9)
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('results/training_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

# Gráfica de barras: Accuracy final
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Validation Accuracy
config_names = list(all_results.keys())
val_accs = [all_results[name]['val_accuracy'] for name in config_names]

axes[0].bar(range(len(config_names)), val_accs, color='#3498db', alpha=0.8, edgecolor='black')
axes[0].set_xticks(range(len(config_names)))
axes[0].set_xticklabels(config_names, rotation=45, ha='right')
axes[0].set_ylabel('Accuracy', fontsize=12)
axes[0].set_title('Validation Accuracy por Configuración', fontsize=12, fontweight='bold')
axes[0].grid(True, alpha=0.3, axis='y')

# Validation Loss
val_losses = [all_results[name]['val_loss'] for name in config_names]

axes[1].bar(range(len(config_names)), val_losses, color='#e74c3c', alpha=0.8, edgecolor='black')
axes[1].set_xticks(range(len(config_names)))
axes[1].set_xticklabels(config_names, rotation=45, ha='right')
axes[1].set_ylabel('Loss', fontsize=12)
axes[1].set_title('Validation Loss por Configuración', fontsize=12, fontweight='bold')
axes[1].grid(True, alpha=0.3, axis='y')

# Training Time
train_times = [all_results[name]['training_time'] for name in config_names]

axes[2].bar(range(len(config_names)), train_times, color='#2ecc71', alpha=0.8, edgecolor='black')
axes[2].set_xticks(range(len(config_names)))
axes[2].set_xticklabels(config_names, rotation=45, ha='right')
axes[2].set_ylabel('Tiempo (segundos)', fontsize=12)
axes[2].set_title('Tiempo de Entrenamiento', fontsize=12, fontweight='bold')
axes[2].grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.savefig('results/metrics_comparison.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_2587/1414932828.py:22: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# # 10. Matriz de Confusión del Mejor Modelo

# %%
best_name = best_config[0]
fig, ax = plt.subplots(1, 1, figsize=(10, 8))

sns.heatmap(results_test['cm'], annot=True, fmt='d', cmap='Oranges',
            ax=ax, cbar_kws={'label': 'Cantidad'})
ax.set_xlabel('Predicción', fontsize=11)
ax.set_ylabel('Etiqueta Verdadera', fontsize=11)
ax.set_title(f'Matriz de Confusión - {best_name}\n(Test Set)', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.savefig(f'results/confusion_matrix_best_{best_name}.png', dpi=150, bbox_inches='tight')
plt.show()
